# %%
#files to be imported
import numpy as np
from matplotlib import pyplot as plt

import os ,sys, platform
import time
import cosmopower as cp

import mpi4py
import cobaya
from cobaya import run

#Planks Values
el = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 0, skiprows=1,dtype =float)
el_te = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 0, skiprows=1,dtype =float)
Dl_TT = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_TT_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_TT_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
Dl_EE = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_EE_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_EE_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
Dl_TE = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_TE_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_TE_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
#ells
dl_fac = el*(el+1)/(2*np.pi)
dl_fac_te = el_te*(el_te+1)/(2*np.pi)
#COSMOPOWER
tt_emu = cp.cosmopower_NN(restore=True,restore_filename='COSMO/cmb_TT_NN')
ee_emu = cp.cosmopower_NN(restore=True,restore_filename='COSMO/cmb_EE_NN')
te_emu = cp.cosmopower_PCAplusNN(restore=True,restore_filename='COSMO/cmb_TE_PCAplusNN')

def chi2(tre,teu,trb,pred): #chi^2 model
    #c = ((tre - pred)**2)/((pred)**2)
    c = ((tre - pred)**2)/((teu + trb)**2) # (Real - Model)^2/(Error Up + Error Bottom)^2
    chi = np.sum(c)
    return chi

#time ms to order of time
def time_hr(ms):
    ssm = ms*100
    seconds = int(ssm/100)
    minutes = int(seconds/60)
    hours = int(minutes/60)
    days = int(hours/24)
    sm = int(ssm - seconds*100)
    s = seconds - minutes*60 
    m = minutes - hours*60
    h = hours - days*24
    t = [sm,s,m,h,days]
    xi = ''
    if days == h == m == s == 0 :
        xi = str(sm) +'ms '
    elif days == h == m == 0:
        xi = str(s) +'s ' + str(sm) +' ms'
    elif days == h == 0:
        xi = str(m) + ' min ' + str(s) +'s ' + str(sm) +' ms'
    elif days == 0:
        xi = str(h) + 'hrs '+str(m) + 'min '+str(s) +'s ' + str(sm) +' ms'
    else :
        xi = str(days) +'days ' + str(h) + 'hrs '+str(m) + 'min '+str(s) +'s ' + str(sm) +' ms' 
    return xi #time 

def Find_val(inputrange,array):
    #finding the input value for the  minimum chi2 value
    min_chi2 = np.argmin(array) #position of minimum chi2
    vals = inputrange[min_chi2] #finding Input value of minimum chi2
    return vals

def Cosmo(xe,ze): # function for Cosmopower
    if xe == 'TT':
        tt_spectra = tt_emu.ten_to_predictions_np(ze)
        CO = tt_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
    elif xe == 'EE':
        ee_spectra = ee_emu.ten_to_predictions_np(ze)
        CA = ee_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
        CO = CA[:1995] #since planks data as only 1995 values 
    elif xe == 'TE':
        te_spectra = te_emu.predictions_np(ze)
        CA = te_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
        CO = CA[:1995] #since planks data as only 1995 values 
    else:
        Print('Check Input Range or Data')
    return CO

def Cosmo_Power(omb,omc,h,tau,ns,As): #function for single value cosmopower
    DET = 'TT'
    params = {'omega_b': [omb],'omega_cdm': [omc],'h': [h/100],'tau_reio': [tau],'n_s': [ns],'ln10^{10}A_s': [np.log( 10**10 *(As*1e-9) )],}
    Para = [omb,omc,h,tau,ns,As]
    if DET=='TT':
        pred = Cosmo('TT',params)*dl_fac
        chi = chi2(Dl_TT*dl_fac,Dl_TT_err_up*dl_fac,Dl_TT_err_bot*dl_fac,pred*dl_fac)
    elif DET=='TE':
        pred = Cosmo('TE',params)*dl_fac_te
        chi = chi2(Dl_TE,Dl_TE_err_up,Dl_TE_err_bot,pred)
    elif DET=='EE':
        pred = Cosmo('EE',params)*dl_fac_te
        chi = chi2(Dl_EE,Dl_EE_err_up,Dl_EE_err_bot,pred)
    reference = [omb,omc,h,tau,ns,As,chi]
    return chi #parameter, prediction , chi value

def cobaya_com(Dpar):
    return (10 - np.log(Cosmo_Power(Dpar,0.12,68,0.0546,0.964,2.01)))

# %%
def cobaya_com6(omb,omc,h,tau,ns,AS):
    return (10 - np.log(Cosmo_Power(omb,omc,h,tau,ns,AS)))

# %%
# below is parameters for 6 parameter cosmopower
info = {"likelihood": {"cosmo1": cobaya_com6}}
info["params"] = {
   "omb": {"prior": {"min": 0.001, "max": 0.08}, "ref": 0.022, "proposal": 0.001},
    "omc": {"prior": {"min": 0, "max": 0.9}, "ref": 0.12, "proposal": 0.01},
    "h": {"prior": {"min": 50, "max": 90}, "ref": 66, "proposal": 0.01},
    "tau": {"prior": {"min": 0.01, "max": 0.1}, "ref": 0.054, "proposal": 0.001},
    "ns": {"prior": {"min": 0.3, "max": 4}, "ref": 0.945, "proposal": 0.001},
    "AS": {"prior": {"min": 0.5, "max": 3}, "ref": 2.0196, "proposal": 0.001}}
info["sampler"] = {"mcmc": {"Rminus1_stop": 0.001, "max_tries": 1000}}
updated_info, sampler = run(info)
# Out:
# [cosmo1] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: omb:0.022, omc:0.12, h:66, tau:0.054, ns:0.945, AS:2.0196
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {cosmo1: 142.0}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-02-21 19:07:03 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# D:\Python\project_cosmology\cospo\lib\site-packages\cobaya\collection.py:651: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._data = pd.concat([
# [mcmc]  - Acceptance rate: 0.857
# [mcmc]  - Convergence of means: R-1 = 10.230037 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.784
# [mcmc]  - Convergence of means: R-1 = 8.565383 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.689
# [mcmc]  - Convergence of means: R-1 = 5.538236 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.602
# [mcmc]  - Convergence of means: R-1 = 0.852850 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.522
# [mcmc]  - Convergence of means: R-1 = 3.760266 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 2.248481 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.419
# [mcmc]  - Convergence of means: R-1 = 0.337928 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.382
# [mcmc]  - Convergence of means: R-1 = 1.183252 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.347
# [mcmc]  - Convergence of means: R-1 = 0.509844 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.175570 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.310
# [mcmc]  - Convergence of means: R-1 = 0.252599 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.299
# [mcmc]  - Convergence of means: R-1 = 0.388388 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.359203 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.280
# [mcmc]  - Convergence of means: R-1 = 0.117116 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.271
# [mcmc]  - Convergence of means: R-1 = 0.085951 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.264
# [mcmc]  - Convergence of means: R-1 = 0.048158 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.262
# [mcmc]  - Convergence of means: R-1 = 0.038767 after 3264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.257
# [mcmc]  - Convergence of means: R-1 = 0.042821 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4560 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.045806 after 3648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.047835 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5040 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.045899 after 4032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.243
# [mcmc]  - Convergence of means: R-1 = 0.062819 after 4224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5520 samples accepted.
# [mcmc]  - Acceptance rate: 0.240
# [mcmc]  - Convergence of means: R-1 = 0.053838 after 4416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.237
# [mcmc]  - Convergence of means: R-1 = 0.044576 after 4608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6000 samples accepted.
# [mcmc]  - Acceptance rate: 0.235
# [mcmc]  - Convergence of means: R-1 = 0.049604 after 4800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6240 samples accepted.
# [mcmc]  - Acceptance rate: 0.235
# [mcmc]  - Convergence of means: R-1 = 0.051915 after 4992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6480 samples accepted.
# [mcmc]  - Acceptance rate: 0.234
# [mcmc]  - Convergence of means: R-1 = 0.041596 after 5184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6720 samples accepted.
# [mcmc]  - Acceptance rate: 0.233
# [mcmc]  - Convergence of means: R-1 = 0.029496 after 5376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6960 samples accepted.
# [mcmc]  - Acceptance rate: 0.231
# [mcmc]  - Convergence of means: R-1 = 0.018865 after 5568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7200 samples accepted.
# [mcmc]  - Acceptance rate: 0.229
# [mcmc]  - Convergence of means: R-1 = 0.021756 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7440 samples accepted.
# [mcmc]  - Acceptance rate: 0.227
# [mcmc]  - Convergence of means: R-1 = 0.014901 after 5952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7680 samples accepted.
# [mcmc]  - Acceptance rate: 0.226
# [mcmc]  - Convergence of means: R-1 = 0.028211 after 6144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7920 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.044755 after 6336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-21 19:08:03 : 32371 steps taken, and 8052 accepted.
# [mcmc] Learn + convergence test @ 8160 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.040758 after 6528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8400 samples accepted.
# [mcmc]  - Acceptance rate: 0.223
# [mcmc]  - Convergence of means: R-1 = 0.037055 after 6720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8640 samples accepted.
# [mcmc]  - Acceptance rate: 0.221
# [mcmc]  - Convergence of means: R-1 = 0.031168 after 6912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8880 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.039361 after 7104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9120 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.035757 after 7296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9360 samples accepted.
# [mcmc]  - Acceptance rate: 0.220
# [mcmc]  - Convergence of means: R-1 = 0.054658 after 7488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9600 samples accepted.
# [mcmc]  - Acceptance rate: 0.219
# [mcmc]  - Convergence of means: R-1 = 0.034090 after 7680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9840 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.037884 after 7872 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10080 samples accepted.
# [mcmc]  - Acceptance rate: 0.218
# [mcmc]  - Convergence of means: R-1 = 0.028282 after 8064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10320 samples accepted.
# [mcmc]  - Acceptance rate: 0.217
# [mcmc]  - Convergence of means: R-1 = 0.036213 after 8256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10560 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.036075 after 8448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10800 samples accepted.
# [mcmc]  - Acceptance rate: 0.216
# [mcmc]  - Convergence of means: R-1 = 0.036226 after 8640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11040 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.038402 after 8832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11280 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.034435 after 9024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11520 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.034475 after 9216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11760 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.038830 after 9408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12000 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.042698 after 9600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12240 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.046374 after 9792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12480 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.050560 after 9984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12720 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.041652 after 10176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12960 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.036495 after 10368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13200 samples accepted.
# [mcmc]  - Acceptance rate: 0.215
# [mcmc]  - Convergence of means: R-1 = 0.029270 after 10560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13440 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.027786 after 10752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13680 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.027712 after 10944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13920 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.027936 after 11136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14160 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.026170 after 11328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14400 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.026171 after 11520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-21 19:09:03 : 63079 steps taken, and 14524 accepted.
# [mcmc] Learn + convergence test @ 14640 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.023081 after 11712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14880 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.023110 after 11904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15120 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.017695 after 12096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15360 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.019208 after 12288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15600 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.020645 after 12480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15840 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.022220 after 12672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16080 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.018597 after 12864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16320 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.025196 after 13056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16560 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.025129 after 13248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16800 samples accepted.
# [mcmc]  - Acceptance rate: 0.214
# [mcmc]  - Convergence of means: R-1 = 0.019667 after 13440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17040 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.018844 after 13632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17280 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.022331 after 13824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17520 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.020493 after 14016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17760 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.021175 after 14208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18000 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.023729 after 14400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18240 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.021338 after 14592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18480 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.021199 after 14784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18720 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.019433 after 14976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18960 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.016140 after 15168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19200 samples accepted.
# [mcmc]  - Acceptance rate: 0.213
# [mcmc]  - Convergence of means: R-1 = 0.013616 after 15360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19440 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.012478 after 15552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19680 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.014620 after 15744 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19920 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.011818 after 15936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20160 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.011669 after 16128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20400 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.012754 after 16320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20640 samples accepted.
# [mcmc]  - Acceptance rate: 0.212
# [mcmc]  - Convergence of means: R-1 = 0.014049 after 16512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 
accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 186000 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002586 after 148800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 186240 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002532 after 148992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 186480 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002385 after 149184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 186720 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002434 after 149376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 186960 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002261 after 149568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 187200 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002236 after 149760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 187440 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002199 after 149952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 187680 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002234 after 150144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 187920 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002316 after 150336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-21 19:36:03 : 894117 steps taken, and 188053 accepted.
# [mcmc] Learn + convergence test @ 188160 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002350 after 150528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 188400 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002445 after 150720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 188640 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002335 after 150912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 188880 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002287 after 151104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 189120 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002424 after 151296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 189360 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002363 after 151488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 189600 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002373 after 151680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 189840 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002343 after 151872 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 190080 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002291 after 152064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 190320 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002341 after 152256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 190560 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001947 after 152448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 190800 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002076 after 152640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 191040 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001933 after 152832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 191280 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001990 after 153024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 191520 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001986 after 153216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 191760 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.002002 after 153408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 192000 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001969 after 153600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 192240 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001824 after 153792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 192480 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001813 after 153984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 192720 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001791 after 154176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 192960 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001558 after 154368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 193200 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001519 after 154560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 193440 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001481 after 154752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 193680 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001486 after 154944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 193920 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001596 after 155136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 194160 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001684 after 155328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 194400 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001740 after 155520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 194640 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001755 after 155712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-21 19:37:03 : 925205 steps taken, and 194711 accepted.
# [mcmc] Learn + convergence test @ 194880 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001706 after 155904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 195120 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001675 after 156096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 195360 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001794 after 156288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 195600 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001771 after 156480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 195840 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001596 after 156672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 196080 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001484 after 156864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 196320 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001362 after 157056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 196560 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001280 after 157248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 196800 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001275 after 157440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 197040 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001439 after 157632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 197280 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001232 after 157824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 197520 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001080 after 158016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 197760 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.000976 after 158208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 198000 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.001048 after 158400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 198240 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.000971 after 158592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 198480 samples accepted.
# [mcmc]  - Acceptance rate: 0.209
# [mcmc]  - Convergence of means: R-1 = 0.000758 after 158784 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.033444 after 198480 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 198480 accepted steps.

# %%
# %matplotlib inline
import getdist.plots as gdplt

gdsamples = sampler.products(to_getdist=True)["sample"]
gdplot = gdplt.get_subplot_plotter(width_inch=5)
gdplot.triangle_plot(gdsamples, ["omb","omc","h","tau","ns","AS"], filled=True)
print(np.shape(gdsamples[6]))
# Out:
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'
# [root] *WARNING* auto bandwidth for h very small or failed (h=0.0005258950310140058,N_eff=47796.61408002233). Using fallback (h=0.04641940934365663)
# (198480,)

# %%
p = ["omb","omc","h","tau","ns","AS"]
s = gdsamples.samples[np.argmin(gdsamples.loglikes)]
for i in range(6):
    print("For the parameter ",p[i]," The acquired value is",s[i])
# Out:
# For the parameter  omb  The acquired value is 0.023699629449640682
# For the parameter  omc  The acquired value is 0.09982103833112063
# For the parameter  h  The acquired value is 76.51958808401402
# For the parameter  tau  The acquired value is 0.06680771398814594
# For the parameter  ns  The acquired value is 0.9790884417126655
# For the parameter  AS  The acquired value is 2.0907750840091626

# %%
arjun = ['hlo','red']
if 'green' in arjun:
    print('hi')
