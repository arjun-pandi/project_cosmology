# %% [markdown]
# <h1>Comparison of parameters</h1>
# <p><ul>
#     <li>Input files</li>
#     <li>Compare 1 D parameters</li>
#     <li>Compare 2 D parameters</li>
#     <li>Compare 3 D parameters</li>
# </ul></p>

# %%
#files to be imported
import numpy as np
from matplotlib import pyplot as plt
import camb
from camb import model, initialpower
import tensorflow as tf

import os ,sys, platform
import time
import cosmopower as cp
import multiprocessing
from multiprocessing import Pool
import threading

#Planks Values
el = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 0, skiprows=1,dtype =float)
el_te = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 0, skiprows=1,dtype =float)
Dl_TT = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_TT_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_TT_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
Dl_EE = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_EE_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_EE_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
Dl_TE = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_TE_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_TE_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
#ells
dl_fac = el*(el+1)/(2*np.pi)
dl_fac_te = el_te*(el_te+1)/(2*np.pi)
#COSMOPOWER
tt_emu = cp.cosmopower_NN(restore=True,restore_filename='COSMO/cmb_TT_NN')
ee_emu = cp.cosmopower_NN(restore=True,restore_filename='COSMO/cmb_EE_NN')
te_emu = cp.cosmopower_PCAplusNN(restore=True,restore_filename='COSMO/cmb_TE_PCAplusNN')

def Cosmo(xe,ze): # function for Cosmopower
    if xe == 'TT':
        tt_spectra = tt_emu.ten_to_predictions_np(ze)
        CO = tt_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
    elif xe == 'EE':
        ee_spectra = ee_emu.ten_to_predictions_np(ze)
        CA = ee_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
        CO = CA[:1995] #since planks data as only 1995 values 
    elif xe == 'TE':
        te_spectra = te_emu.predictions_np(ze)
        CA = te_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
        CO = CA[:1995] #since planks data as only 1995 values 
    else:
        Print('Check Input Range or Data')
    return CO

def Camb_pp(ell,ell_max,parameter,x,lens_accuracy=0): #Function for CAMb
    #camb model pars
    pars = camb.CAMBparams()
    pars.set_cosmology(H0 = par["H0"], ombh2=par["ombh2"], omch2=par["omch2"], mnu=par["mnu"], omk=par["omk"], tau=par["tau"])
    pars.InitPower.set_params(As=par["As"], ns=par["ns"], r=par["r"])
    pars.set_for_lmax(ell_max-1, lens_potential_accuracy=float(lens_accuracy));
    #camb result and power spectra
    camb_results = camb.get_results(pars)
    powers = camb_results.get_cmb_power_spectra(pars, CMB_unit="muK")#,raw_cl=True)
    
    if x == 'TT':
        #CAMB TT
        cambq = powers['lensed_scalar'][:, 0][2:ell_max]
    elif x == 'EE':
        #CAMB EE
        cambq = powers['lensed_scalar'][:, 1][2:ell_max]
    elif x == 'TE':
        #CAMB TE
        cambq = powers['lensed_scalar'][:, 3][2:ell_max]
    else:
        #CAMB TE EE
        cambq = None  
    return cambq 

def chi2(tre,teu,trb,pred): #chi^2 model
    #c = ((tre - pred)**2)/((pred)**2)
    c = ((tre - pred)**2)/((teu + trb)**2) # (Real - Model)^2/(Error Up + Error Bottom)^2
    chi = np.sum(c)
    return chi

#time ms to order of time
def time_hr(ms):
    ssm = ms*100
    seconds = int(ssm/100)
    minutes = int(seconds/60)
    hours = int(minutes/60)
    days = int(hours/24)
    sm = int(ssm - seconds*100)
    s = seconds - minutes*60 
    m = minutes - hours*60
    h = hours - days*24
    t = [sm,s,m,h,days]
    xi = ''
    if days == h == m == s == 0 :
        xi = str(sm) +'ms '
    elif days == h == m == 0:
        xi = str(s) +'s ' + str(sm) +' ms'
    elif days == h == 0:
        xi = str(m) + ' min ' + str(s) +'s ' + str(sm) +' ms'
    elif days == 0:
        xi = str(h) + 'hrs '+str(m) + 'min '+str(s) +'s ' + str(sm) +' ms'
    else :
        xi = str(days) +'days ' + str(h) + 'hrs '+str(m) + 'min '+str(s) +'s ' + str(sm) +' ms' 
    return xi

def Cosmo_Power(DET,omb,omc,h,tau,ns,As): #function for single value cosmopower
   
    params = {'omega_b': [omb],'omega_cdm': [omc],'h': [h/100],'tau_reio': [tau],'n_s': [ns],'ln10^{10}A_s': [np.log( 10**10 *(As*1e-9) )],}
    Para = [omb,omc,h,tau,ns,As]
    if DET=='TT':
        pred = Cosmo('TT',params)*dl_fac
        chi = chi2(Dl_TT*dl_fac,Dl_TT_err_up*dl_fac,Dl_TT_err_bot*dl_fac,pred*dl_fac)
    elif DET=='TE':
        pred = Cosmo('TE',params)*dl_fac_te
        chi = chi2(Dl_TE,Dl_TE_err_up,Dl_TE_err_bot,pred)
    elif DET=='EE':
        pred = Cosmo('EE',params)*dl_fac_te
        chi = chi2(Dl_EE,Dl_EE_err_up,Dl_EE_err_bot,pred)
    return Para,pred,chi #parameter, prediction , chi value

def Find_val(inputrange,array):
    #finding the input value for the  minimum chi2 value
    min_chi2 = np.argmin(array) #position of minimum chi2
    vals = inputrange[min_chi2] #finding Input value of minimum chi2
    return vals

def for_cosmo(DET,DEF,range,para):
    #finding the fitted value for single values
    pred_arr=[]
    chi_arr=[]
    if DEF=='omb':
        for val in range:
            des = Cosmo_Power(DET,val,para[1],para[2],para[3],para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])            
    elif DEF=='omc':
        for val in range:
            des = Cosmo_Power(DET,para[0],val,para[2],para[3],para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='h':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],val,para[3],para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='tau':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],para[2],val,para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='ns':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],para[2],para[3],val,para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='as':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],para[2],para[3],para[4],val)
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    else:
        Print("check DATA type. ERROR!")
        
    fitted_val = Find_val(range,chi_arr)
    return fitted_val #returns best fitted value with chi2

def iter_pars(DET,rang,para):
    #function to iterate each parameters by setting all initial parameter and runnning each time and setting the parameter
    omb = for_cosmo(DET,'omb',rang[0],para)
    para[0] = omb
    omc = for_cosmo(DET,'omc',rang[1],para)
    para[1] = omc
    h = for_cosmo(DET,'h',rang[2],para)
    para[2] = h
    tau = for_cosmo(DET,'tau',rang[3],para)
    para[3] = tau
    ns = for_cosmo(DET,'ns',rang[4],para)
    para[4] = ns
    As = for_cosmo(DET,'as',rang[5],para)
    para[5] = As
    para = [omb,omc,h,tau,ns,As]
    return para # return parameter
    
def loop_it(DET,rang,paras,tims):
    #this function finding parameters for several 'times', finding errors for each parameters
    omb = []
    omc = []
    h = []
    tau = []
    ns = []
    As = []
    for i in range(tims):
        para = iter_pars(DET,rang,paras)
        omb.append(para[0])
        omc.append(para[1])
        h.append(para[2])
        tau.append(para[3])
        ns.append(para[4])
        As.append(para[5])

    omb_error = np.std(omb)
    omc_error = np.std(omc)
    h_error = np.std(h)
    tau_error = np.std(tau)
    ns_error = np.std(ns)
    As_error = np.std(As)
    para_error = [omb_error,omc_error,h_error,tau_error,ns_error,As_error ]
    para = [np.average(omb),np.average(omc),np.average(h),np.average(tau),np.average(ns),np.average(As)]
    #returning prameters and its errors which is standard deviations
    return para,para_error

#double parameters functions
def cosmopo(DET,par_arr,da='none',db='none'): #cosmopower for a array of values
    pre = []
    chi = []
    arr = []
    for par in par_arr: #iterating each parameters in the array
        set =  Cosmo_Power(DET,par[0],par[1],par[2],par[3],par[4],par[5])
        set_pre = set[1]
        set_chi = set[2]
        pre.append(set_pre)
        chi.append(set_chi)
        arr.append([par[0],par[1],par[2],par[3],par[4],par[5],da,db,set_chi])
    fit_par = Find_val(par_arr,chi) #finding the best fitted parameters from the array
    return fit_par,arr

def par_arr(DEF,rang,par): #for creating array of parameters for one set of range
    arr = []
    for i in rang:
        if DEF == 'omb':
            arr.append([i,par[1],par[2],par[3],par[4],par[5]])
        elif DEF == 'omc':
            arr.append([par[0],i,par[2],par[3],par[4],par[5]])
        elif DEF == 'h':
            arr.append([par[0],par[1],i,par[3],par[4],par[5]])
        elif DEF == 'tau':
            arr.append([par[0],par[1],par[2],i,par[4],par[5]])
        elif DEF == 'ns':
            arr.append([par[0],par[1],par[2],par[3],i,par[5]])
        elif DEF == 'as':
            arr.append([par[0],par[1],par[2],par[3],par[4],i])
        else :
            print('check input par')

    return arr #returns only a arrray

def par_arr_2(DEF1,DEF2,rang1,rang2,par): #creating array of parameters for 2 sets of ranges
    arr = []
    first_arr = par_arr(DEF1,rang1,par)#initial single array creation
    for i in first_arr: 
        for j in rang2:
            if DEF2 == 'omb':
                arr.append([j,i[1],i[2],i[3],i[4],i[5]])
            elif DEF2 == 'omc':
                arr.append([i[0],j,i[2],i[3],i[4],i[5]])
            elif DEF2 == 'h':
                arr.append([i[0],i[1],j,i[3],i[4],i[5]])
            elif DEF2 == 'tau':
                arr.append([i[0],i[1],i[2],j,i[4],i[5]])
            elif DEF2 == 'ns':
                arr.append([i[0],i[1],i[2],i[3],j,i[5]])
            elif DEF2 == 'as':
                arr.append([i[0],i[1],i[2],i[3],i[4],j])
            else:
                print("check")

    return arr,DEF1,DEF2 #returns the array rang1*rang2 and parameter1 and 2

def cospor(DET,i,pars_arr,ran_arr,par,ret_arr=False): #for simple Calculation inputs are Data type,iteration number,parameter name array, range array,parameter
    pars = ["omb","omc","h","tau","ns","as"]
    da = pars_arr[i][0] #getting parameter name 1
    db = pars_arr[i][1] #getting parameter name 2
    Ra1 = ran_arr[pars.index(da)] # range of parameter1 
    Ra2 = ran_arr[pars.index(db)] # range of parameter2
    arr = par_arr_2(da,db,Ra1,Ra2,par)[0] #array generation 
    parm = cosmopo(DET,arr,da,db) #Cosmopowers on array
    arr = parm[1]
    rev = [parm[0],da,db] #fitted parameters for given range i
    np.save('likeliyhood/chi_arr/'+da+'_'+db,parm[1])
    if ret_arr==True:
        return rev,arr
    else:
        return rev

def cospors(rang_arr,par,par_arr = None,plot = False,thread = False):
    pars = ["omb","omc","h","tau","ns","as"]
    pars_arr = []
    #array generation with parameters names it also as rules that [a,a] does not exist,[a,b] or [a,b] pairs repeat once
    if par_arr == None:
        for xi in pars:
            for yi in pars:
                if xi == yi:
                    pass
                else:
                    pars_arr.append([xi,yi])

        for xi in pars:
            for yi in pars:
                for ys in pars_arr:
                    if [xi,yi]==ys:
                        pars_arr.remove([yi,xi])
                    else:
                        pass
    else:
        pars_arr = par_arr
        
    threads = [] #multithreading for fast calculations
    par_ar = [] 
    par_a = []#this is the results parameters stored

    for i in range(len(pars_arr)): # number of calculations
        if thread == False: #Direct calculations without threading
            par_a.append(cospor('TT',i,pars_arr,rang_arr,par)) #value stored as[[parameters],name of par1,2]
        else:
            t = threading.Thread(target=lambda i=i: par_ar.append(cospor("TT",i,pars_arr,rang_arr,par,True))) #multithreading parameters
            threads.append(t) #saving the threads
            t.start() #start threads  
            
            for t in threads: # for join threads at closing
                t.join() # on joining no threads is in order

    print_arr = []
    plot_arr = []
    if thread == True:
        for i in par_ar:
            par_a.append(i[0])
            plot_arr.append(i[1])

    if plot == True:
        for i in plot_arr:
            arrar = []
            xy = []
            yy = []
            z = []
            da = i[0][6]
            db = i[0][7]
            for j in i:
                da = j[6]
                db = j[7]
                chi = j[8]
                xi = j[pars.index(da)]
                yi = j[pars.index(db)]
                arrar.append([xi,yi,chi])
            print_arr.append([da,db,arrar])
            np.save('likeliyhood/plot_arr/'+da+'_'+db,arrar)
            plotif(arrar,da,db)
        
    runs =[par_a , print_arr]
    return runs#[[parameters],name of parameter1 and parameter2] in a list

def de_par(par_aa,prints=False): #for finding average and standard deviation of given parameters
    pars = ["omb","omc","h","tau","ns","as"]
    par = [[],[],[],[],[],[]]
    for i in par_aa:
        par[pars.index(i[1])].append(i[0][pars.index(i[1])])
        par[pars.index(i[2])].append(i[0][pars.index(i[2])])
    pam = [[],[],[],[],[],[]]
    rev =[]
    for i in range(len(pars)):
        pam[i].append([pars[i],[np.average(par[i])],[np.std(par[i])]])
    
    for i in pam:
        if prints == True:
            print(i[0][0],':',np.round(i[0][1],5),'+-',np.round(i[0][2],10))
        else:
            rev.append([i[0][0],':',np.round(i[0][1],5),'+-',np.round(i[0][2],10)])    
    return rev #list(parameters:value +- standard deviation)

def plotif(arri,da,db,drae = False):
    d = [[],[],[]]
    for j in range(len(arri)):
        d[0].append(arri[j][0])
        d[1].append(arri[j][1])
        d[2].append(arri[j][2])

    e = [np.unique(d[0]),np.unique(d[1]),np.rot90(np.reshape(d[2],(np.shape(np.unique(d[0]))[0],np.shape(np.unique(d[1]))[0])))]
    extent = (np.min(e[0]),np.max(e[0]),np.min(e[1]),np.max(e[1]))
    f = np.log(e[2])
    dd =[da,db]
    if drae ==False:
        par_1 = e[0][np.argmin(np.nanmean(f,axis = 0))]
        par_2 = e[1][np.argmin(np.nanmean(f,axis = 1))]
        plt.axhline(par_1)
        plt.axvline(par_2)
        plt.xlabel(da)
        plt.ylabel(db)
        plt.imshow(f,aspect='auto',cmap=plt.cm.Spectral,extent= extent)
        plt.colorbar()
        plt.show()
    else: 
        fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12,4))
        '''deltachi_1 = np.max(e[2]) - 2*np.log(np.mean(e[2],axis=0))
        deltachi_2 = np.max(e[2]) - 2*np.log(np.mean(e[2],axis=1))
        '''
        #plt.plot(e[1],np.log(np.mean(e[2],axis=1)),xlabel=db,ylabel='chi_sq')
    
        deltachi_1=np.log(np.mean(e[2],axis=0))/np.min(np.log(np.mean(e[2],axis=0)))
        deltachi_2=np.log(np.mean(e[2],axis=1))/np.min(np.log(np.mean(e[2],axis=1)))
        ax1.plot(e[0],deltachi_1)
        ax1.set_xlabel(dd[0])
        ax2.set_xlabel(dd[1])
        ax1.set_ylabel('chi_sq')
        ax2.set_ylabel('chi_sq')
        

        ax2.plot(e[1],deltachi_2)
        plt.show()
        print('Resulted Values')
        for i in range(2):

            s = np.mean(e[2],axis=i)/np.min(np.mean(e[2],axis=i))
            eff = 1.01
            es = []
            ess = []
            for l in range(len(e[i])):
                if s[l] > eff:
                    es.append(0)
                elif s[l] <= eff:
                    es.append(e[i][l])
                    ess.append(e[i][l])
            er = [np.min(ess),np.average(ess),np.max(ess)]
            error = np.std(er)

            
            print(dd[i],':',d[i][np.argmin(np.mean(e[2],axis=i))],'+_',error)
        
    return e

def Cosmo_Power(omb,omc,h,tau,ns,As): #function for single value cosmopower
    DET = 'TT'
    params = {'omega_b': [omb],'omega_cdm': [omc],'h': [h/100],'tau_reio': [tau],'n_s': [ns],'ln10^{10}A_s': [np.log( 10**10 *(As*1e-9) )],}
    Para = [omb,omc,h,tau,ns,As]
    if DET=='TT':
        pred = Cosmo('TT',params)*dl_fac
        chi = chi2(Dl_TT*dl_fac,Dl_TT_err_up*dl_fac,Dl_TT_err_bot*dl_fac,pred*dl_fac)
    elif DET=='TE':
        pred = Cosmo('TE',params)*dl_fac_te
        chi = chi2(Dl_TE,Dl_TE_err_up,Dl_TE_err_bot,pred)
    elif DET=='EE':
        pred = Cosmo('EE',params)*dl_fac_te
        chi = chi2(Dl_EE,Dl_EE_err_up,Dl_EE_err_bot,pred)
    reference = [omb,omc,h,tau,ns,As,chi]
    return chi #parameter, prediction , chi value

# %% [markdown]
# <h1>Code for 1 parameter</h1>

# %% [markdown]
# <h3>Normal</h3>

# %%
arr = [[0.021,0.023],[0.11,0.13],[67,68],[0.05,0.06],[0.9,1],[2,2.2]]

# %%
#print(Cosmo_Power('EE',0.0221,0.1205,67.29,0.0542,0.945,2.0969)[1])
omb = np.arange(0.021,0.023,0.00001)
omc = np.arange(0.11,0.13,0.0001)
h = np.arange(67,68,0.01)
tau = np.arange(0.05,0.06,0.00001)
ns = np.arange(0.9,1,0.001)
As = np.arange(2,2.2,0.0001)
rangee = [omb,omc,h,tau,ns,As]
paras = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
start_time = time.time() #time calculation
p_TT = loop_it('TT',rangee,paras,4) # direct calculations

for x in range(6):
    print(p_TT[0][x],'+-',p_TT[1][x])# looping for print
    
end_time = time.time() #time calculation
tim = time_hr(end_time - start_time) # finding time for excution
print( 'Executed in :',tim)
# Out:
# 0.02227249999999995 +- 0.00019841559918513664
# 0.1205250000000003 +- 0.0003031088913245622
# 67.25500000000014 +- 0.032787192621526774
# 0.05019750000000006 +- 0.00034208003449495803
# 0.9637500000000001 +- 0.004968651728587952
# 2.0809000000001707 +- 0.003025723054087839
# Executed in : 1 min 10s 3 ms

# %% [markdown]
# <h3>Cobaya For 1 paramter</h3>

# %%
def cobaya_1(arr,DET):

    if DET == 'omb':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Power(Dpar,0.1208,67.29,0.0542,0.945,2.0969)))
    elif DET == 'omc':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Power(0.0228,Dpar,67.29,0.0542,0.945,2.0969)))
    elif DET == 'h':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Power(0.0228,0.1208,Dpar,0.0542,0.945,2.0969)))
    elif DET == 'tau':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Power(0.0228,0.1208,67.29,Dpar,0.945,2.0969)))
    elif DET == 'ns':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Power(0.0228,0.1208,67.29,0.0542,Dpar,2.0969)))
    elif DET == 'AS':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Power(0.0228,0.1208,67.29,0.0542,0.945,Dpar)))
    # below is parameters for 6 parameter cosmopower
    info = {"likelihood": {"cosmo": cobaya_com}}
    info["params"] = {
        "Dpar": {"prior": {"min": arr[0], "max": arr[1]}, "ref": arr[2], "proposal": 0.001},}
    info["sampler"] = {"mcmc": {"Rminus1_stop": 0.0001, "max_tries": 1000}}

    from cobaya import run
    updated_info, sampler = run(info)

    import getdist.plots as gdplt

    gdsamples = sampler.products(to_getdist=True)["sample"]
    ser = gdsamples.samples[np.argmin(gdsamples.loglikes)][0]

    return ser

# %%
df = []
for i in range(6):
    par = ["omb","omc","h","tau","ns","AS"]
    pare = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
    se = cobaya_1([arr[i][0],arr[i][1],pare[i]],par[i])
    df.append(se)
# Out:
# [cosmo] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: Dpar:0.0228
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {cosmo: 171.0}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-02-27 21:54:49 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 40 samples accepted.
# [mcmc]  - Acceptance rate: 0.069
# [mcmc]  - Convergence of means: R-1 = 0.178854 after 32 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# D:\Python\project_cosmology\cospo\lib\site-packages\cobaya\collection.py:651: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._data = pd.concat([
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.145
# [mcmc]  - Convergence of means: R-1 = 0.081242 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.237
# [mcmc]  - Convergence of means: R-1 = 0.204193 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.367
# [mcmc]  - Convergence of means: R-1 = 0.005560 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 200 samples accepted.
# [mcmc]  - Acceptance rate: 0.495
# [mcmc]  - Convergence of means: R-1 = 0.016320 after 160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.496
# [mcmc]  - Convergence of means: R-1 = 0.009049 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 280 samples accepted.
# [mcmc]  - Acceptance rate: 0.516
# [mcmc]  - Convergence of means: R-1 = 0.044673 after 224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.514
# [mcmc]  - Convergence of means: R-1 = 0.009273 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.501
# [mcmc]  - Convergence of means: R-1 = 0.055743 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.500
# [mcmc]  - Convergence of means: R-1 = 0.067488 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 440 samples accepted.
# [mcmc]  - Acceptance rate: 0.500
# [mcmc]  - Convergence of means: R-1 = 0.017475 after 352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.497
# [mcmc]  - Convergence of means: R-1 = 0.017907 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 520 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.021874 after 416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.017437 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.478
# [mcmc]  - Convergence of means: R-1 = 0.002573 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.011471 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 680 samples accepted.
# [mcmc]  - Acceptance rate: 0.481
# [mcmc]  - Convergence of means: R-1 = 0.019264 after 544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.478
# [mcmc]  - Convergence of means: R-1 = 0.013772 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 760 samples accepted.
# [mcmc]  - Acceptance rate: 0.478
# [mcmc]  - Convergence of means: R-1 = 0.010591 after 608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.479
# [mcmc]  - Convergence of means: R-1 = 0.007236 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.000561 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.490
# [mcmc]  - Convergence of means: R-1 = 0.002480 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 920 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.005193 after 736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.011483 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1000 samples accepted.
# [mcmc]  - Acceptance rate: 0.490
# [mcmc]  - Convergence of means: R-1 = 0.013937 after 800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.010340 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.004739 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.478
# [mcmc]  - Convergence of means: R-1 = 0.002495 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1160 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.003385 after 928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.002100 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1240 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.009692 after 992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.011189 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.013257 after 1056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.005657 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1400 samples accepted.
# [mcmc]  - Acceptance rate: 0.469
# [mcmc]  - Convergence of means: R-1 = 0.001967 after 1120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.000769 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1480 samples accepted.
# [mcmc]  - Acceptance rate: 0.465
# [mcmc]  - Convergence of means: R-1 = 0.003423 after 1184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.464
# [mcmc]  - Convergence of means: R-1 = 0.006456 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.466
# [mcmc]  - Convergence of means: R-1 = 0.002531 after 1248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.464
# [mcmc]  - Convergence of means: R-1 = 0.004599 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1640 samples accepted.
# [mcmc]  - Acceptance rate: 0.464
# [mcmc]  - Convergence of means: R-1 = 0.006206 after 1312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.466
# [mcmc]  - Convergence of means: R-1 = 0.005109 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1720 samples accepted.
# [mcmc]  - Acceptance rate: 0.467
# [mcmc]  - Convergence of means: R-1 = 0.007655 after 1376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.009998 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.469
# [mcmc]  - Convergence of means: R-1 = 0.007432 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.006555 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1880 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.004477 after 1504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.005548 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1960 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.009242 after 1568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.009104 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.007644 after 1632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.006791 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2120 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.011013 after 1696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.010482 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2200 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.007296 after 1760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.007205 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.004086 after 1824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.005045 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2360 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.005546 after 1888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.006350 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2440 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.008333 after 1952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.005039 after 1984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.005569 after 2016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.008595 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2600 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.009385 after 2080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.010833 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2680 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.016277 after 2144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.012628 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.011447 after 2208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2800 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.012826 after 2240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2840 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.004773 after 2272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.006131 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2920 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.005743 after 2336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2960 samples accepted.
# [mcmc]  - Acceptance rate: 0.476
# [mcmc]  - Convergence of means: R-1 = 0.004499 after 2368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.005342 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.005291 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3080 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.005567 after 2464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.003625 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3160 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.005199 after 2528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.006687 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.007297 after 2592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3280 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.004666 after 2624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3320 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.003953 after 2656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.006031 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3400 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.006067 after 2720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3440 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.008366 after 2752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.008467 after 2784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.008050 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3560 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.007871 after 2848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.012314 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3640 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.009623 after 2912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.006986 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3720 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.005149 after 2976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3760 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.004111 after 3008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3800 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.001975 after 3040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.001648 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3880 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.001955 after 3104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3920 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.003372 after 3136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3960 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001898 after 3168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001265 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4040 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.000825 after 3232 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.000584 after 3264 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.063969 after 4080 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 4080 accepted steps.
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'
# [root] *WARNING* outlier fraction 0.0029411764705882353
# [cosmo] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: Dpar:0.1208
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {cosmo: 225.0}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-02-27 21:55:10 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 40 samples accepted.
# [mcmc]  - Acceptance rate: 0.615
# [mcmc]  - Convergence of means: R-1 = 0.940124 after 32 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# D:\Python\project_cosmology\cospo\lib\site-packages\cobaya\collection.py:651: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._data = pd.concat([
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.587
# [mcmc]  - Convergence of means: R-1 = 0.031679 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.578
# [mcmc]  - Convergence of means: R-1 = 0.054477 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.569
# [mcmc]  - Convergence of means: R-1 = 0.004728 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 200 samples accepted.
# [mcmc]  - Acceptance rate: 0.537
# [mcmc]  - Convergence of means: R-1 = 0.039396 after 160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.526
# [mcmc]  - Convergence of means: R-1 = 0.022277 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 280 samples accepted.
# [mcmc]  - Acceptance rate: 0.530
# [mcmc]  - Convergence of means: R-1 = 0.032163 after 224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.522
# [mcmc]  - Convergence of means: R-1 = 0.020434 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.529
# [mcmc]  - Convergence of means: R-1 = 0.035934 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.532
# [mcmc]  - Convergence of means: R-1 = 0.046447 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 440 samples accepted.
# [mcmc]  - Acceptance rate: 0.532
# [mcmc]  - Convergence of means: R-1 = 0.024891 after 352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.522
# [mcmc]  - Convergence of means: R-1 = 0.024135 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 520 samples accepted.
# [mcmc]  - Acceptance rate: 0.512
# [mcmc]  - Convergence of means: R-1 = 0.038015 after 416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.516
# [mcmc]  - Convergence of means: R-1 = 0.035410 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.512
# [mcmc]  - Convergence of means: R-1 = 0.023920 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.509
# [mcmc]  - Convergence of means: R-1 = 0.031750 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 680 samples accepted.
# [mcmc]  - Acceptance rate: 0.502
# [mcmc]  - Convergence of means: R-1 = 0.023680 after 544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.500
# [mcmc]  - Convergence of means: R-1 = 0.019558 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 760 samples accepted.
# [mcmc]  - Acceptance rate: 0.499
# [mcmc]  - Convergence of means: R-1 = 0.026262 after 608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.500
# [mcmc]  - Convergence of means: R-1 = 0.022017 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.500
# [mcmc]  - Convergence of means: R-1 = 0.014195 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.499
# [mcmc]  - Convergence of means: R-1 = 0.010207 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 920 samples accepted.
# [mcmc]  - Acceptance rate: 0.504
# [mcmc]  - Convergence of means: R-1 = 0.004852 after 736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.505
# [mcmc]  - Convergence of means: R-1 = 0.004037 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1000 samples accepted.
# [mcmc]  - Acceptance rate: 0.503
# [mcmc]  - Convergence of means: R-1 = 0.005489 after 800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.500
# [mcmc]  - Convergence of means: R-1 = 0.003886 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.502
# [mcmc]  - Convergence of means: R-1 = 0.002779 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.499
# [mcmc]  - Convergence of means: R-1 = 0.003204 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1160 samples accepted.
# [mcmc]  - Acceptance rate: 0.497
# [mcmc]  - Convergence of means: R-1 = 0.003742 after 928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.498
# [mcmc]  - Convergence of means: R-1 = 0.001014 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1240 samples accepted.
# [mcmc]  - Acceptance rate: 0.496
# [mcmc]  - Convergence of means: R-1 = 0.001949 after 992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.496
# [mcmc]  - Convergence of means: R-1 = 0.005269 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.490
# [mcmc]  - Convergence of means: R-1 = 0.004130 after 1056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.490
# [mcmc]  - Convergence of means: R-1 = 0.005554 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1400 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.004676 after 1120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.002039 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1480 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.002652 after 1184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.004964 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.003525 after 1248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.002701 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1640 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.001220 after 1312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.002256 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1720 samples accepted.
# [mcmc]  - Acceptance rate: 0.482
# [mcmc]  - Convergence of means: R-1 = 0.000663 after 1376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.482
# [mcmc]  - Convergence of means: R-1 = 0.002678 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.480
# [mcmc]  - Convergence of means: R-1 = 0.002104 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.480
# [mcmc]  - Convergence of means: R-1 = 0.002352 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1880 samples accepted.
# [mcmc]  - Acceptance rate: 0.479
# [mcmc]  - Convergence of means: R-1 = 0.001044 after 1504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.001159 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1960 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.000704 after 1568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.001029 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.003175 after 1632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.003188 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2120 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.002356 after 1696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.004442 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2200 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.001538 after 1760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.003287 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.003752 after 1824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.004755 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2360 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.005375 after 1888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.004349 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2440 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.006466 after 1952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.006035 after 1984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.004981 after 2016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.003734 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2600 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.003291 after 2080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.004729 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2680 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.005513 after 2144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.005087 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.004207 after 2208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2800 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.002406 after 2240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2840 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.003805 after 2272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.004545 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2920 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.003349 after 2336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2960 samples accepted.
# [mcmc]  - Acceptance rate: 0.485
# [mcmc]  - Convergence of means: R-1 = 0.002118 after 2368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.003242 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.486
# [mcmc]  - Convergence of means: R-1 = 0.004007 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3080 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.004695 after 2464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.004705 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3160 samples accepted.
# [mcmc]  - Acceptance rate: 0.489
# [mcmc]  - Convergence of means: R-1 = 0.005072 after 2528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.489
# [mcmc]  - Convergence of means: R-1 = 0.003303 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.490
# [mcmc]  - Convergence of means: R-1 = 0.004000 after 2592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3280 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003452 after 2624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3320 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.002607 after 2656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.002665 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3400 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.002425 after 2720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3440 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.001615 after 2752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.495
# [mcmc]  - Convergence of means: R-1 = 0.001262 after 2784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.001763 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3560 samples accepted.
# [mcmc]  - Acceptance rate: 0.495
# [mcmc]  - Convergence of means: R-1 = 0.002269 after 2848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.495
# [mcmc]  - Convergence of means: R-1 = 0.001724 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3640 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.001893 after 2912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.001652 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3720 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.003095 after 2976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3760 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.002600 after 3008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3800 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003872 after 3040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003872 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3880 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.003612 after 3104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3920 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.004406 after 3136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3960 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# [mcmc]  - Convergence of means: R-1 = 0.004461 after 3168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003444 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4040 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.003384 after 3232 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.002841 after 3264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4120 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003029 after 3296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.002577 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4200 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003388 after 3360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4240 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.003309 after 3392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4280 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.004207 after 3424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.491
# [mcmc]  - Convergence of means: R-1 = 0.002754 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4360 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.002680 after 3488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4400 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.002007 after 3520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4440 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.002010 after 3552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [mcmc]  - Acceptance rate: 0.494
# ...
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.030927 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 760 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.017511 after 608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.009789 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.490
# [mcmc]  - Convergence of means: R-1 = 0.009842 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.484
# [mcmc]  - Convergence of means: R-1 = 0.021350 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 920 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.063943 after 736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.041487 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1000 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.022148 after 800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.012443 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.482
# [mcmc]  - Convergence of means: R-1 = 0.008232 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.479
# [mcmc]  - Convergence of means: R-1 = 0.010219 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1160 samples accepted.
# [mcmc]  - Acceptance rate: 0.482
# [mcmc]  - Convergence of means: R-1 = 0.021618 after 928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.030284 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1240 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.030001 after 992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.491
# [mcmc]  - Convergence of means: R-1 = 0.017461 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.007823 after 1056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.012600 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1400 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.010548 after 1120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.489
# [mcmc]  - Convergence of means: R-1 = 0.009868 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1480 samples accepted.
# [mcmc]  - Acceptance rate: 0.491
# [mcmc]  - Convergence of means: R-1 = 0.010728 after 1184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.493
# [mcmc]  - Convergence of means: R-1 = 0.009205 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.492
# [mcmc]  - Convergence of means: R-1 = 0.005734 after 1248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.489
# [mcmc]  - Convergence of means: R-1 = 0.002683 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1640 samples accepted.
# [mcmc]  - Acceptance rate: 0.488
# [mcmc]  - Convergence of means: R-1 = 0.002782 after 1312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.487
# [mcmc]  - Convergence of means: R-1 = 0.004294 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1720 samples accepted.
# [mcmc]  - Acceptance rate: 0.483
# [mcmc]  - Convergence of means: R-1 = 0.009578 after 1376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.481
# [mcmc]  - Convergence of means: R-1 = 0.008658 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.479
# [mcmc]  - Convergence of means: R-1 = 0.017659 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.479
# [mcmc]  - Convergence of means: R-1 = 0.023300 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1880 samples accepted.
# [mcmc]  - Acceptance rate: 0.478
# [mcmc]  - Convergence of means: R-1 = 0.018979 after 1504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.477
# [mcmc]  - Convergence of means: R-1 = 0.012534 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1960 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.007006 after 1568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.007260 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.005127 after 1632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.003754 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2120 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.002243 after 1696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.003763 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2200 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.000361 after 1760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.001466 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001751 after 1824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.001931 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2360 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.002316 after 1888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.002687 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2440 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.002805 after 1952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.003339 after 1984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.002910 after 2016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.003128 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2600 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.003203 after 2080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.469
# [mcmc]  - Convergence of means: R-1 = 0.001501 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2680 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.002302 after 2144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.003345 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.002579 after 2208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2800 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001615 after 2240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2840 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.003061 after 2272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.002861 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2920 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.000894 after 2336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2960 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001461 after 2368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.473
# [mcmc]  - Convergence of means: R-1 = 0.002327 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.002384 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3080 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001927 after 2464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.001995 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3160 samples accepted.
# [mcmc]  - Acceptance rate: 0.472
# [mcmc]  - Convergence of means: R-1 = 0.001530 after 2528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.002171 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.001668 after 2592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3280 samples accepted.
# [mcmc]  - Acceptance rate: 0.471
# [mcmc]  - Convergence of means: R-1 = 0.001762 after 2624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3320 samples accepted.
# [mcmc]  - Acceptance rate: 0.470
# [mcmc]  - Convergence of means: R-1 = 0.002067 after 2656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.467
# [mcmc]  - Convergence of means: R-1 = 0.001486 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3400 samples accepted.
# [mcmc]  - Acceptance rate: 0.467
# [mcmc]  - Convergence of means: R-1 = 0.001005 after 2720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3440 samples accepted.
# [mcmc]  - Acceptance rate: 0.467
# [mcmc]  - Convergence of means: R-1 = 0.001355 after 2752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.466
# [mcmc]  - Convergence of means: R-1 = 0.001946 after 2784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.001583 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3560 samples accepted.
# [mcmc]  - Acceptance rate: 0.469
# [mcmc]  - Convergence of means: R-1 = 0.000699 after 2848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.000612 after 2880 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.032404 after 3600 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 3600 accepted steps.
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'

# %%
print(df)
# Out:
# [0.02261203691568638, 0.12045145697731083, 67.20884917557206, 0.05000052494934571, 0.9633697620920362, 2.1146169196347033]

# %% [markdown]
# <h2>On Comparing</h2>
#
# <table>
#     <tr>
#         <th>Parameter</th>
#         <th>Single Parameter</th>
#         <th>Cobaya Parameter</th>
#     </tr>
#     <tr>
#         <th>OMB</th>
#         <td>0.0222724</td>
#         <td>0.02261203</td>
#     </tr>
#     <tr>
#         <th>OMC</th>
#         <td>0.120525</td>
#         <td>0.12045</td>
#      </tr>
#      <tr>
#         <th>H</th>
#         <td>67.255</td>
#         <td>67.2088</td>
#      </tr>
#      <tr>
#         <th>TAU</th>
#         <td>0.050197</td>
#         <td>0.0500</td>
#     </tr>
#     <tr>
#         <th>NS</th>
#         <td>0.963750</td>
#         <td>0.9633696</td>
#     </tr>
#     <tr>
#         <th>AS</th>
#         <td>2.0809</td>
#         <td>2.1146</td>
#      </tr>
# </table>

# %% [markdown]
# <h1>Comparee 2 parameter</h1>
