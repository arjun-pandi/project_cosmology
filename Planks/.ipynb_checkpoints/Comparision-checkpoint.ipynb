# %% [markdown]
# <h1>Comparison of parameters</h1>
# <p><ul>
#     <li>Input files</li>
#     <li>Compare 1 D parameters</li>
#     <li>Compare 2 D parameters</li>
#     <li>Compare 3 D parameters</li>
# </ul></p>

# %%
#files to be imported
import numpy as np
from matplotlib import pyplot as plt
import camb
from camb import model, initialpower
import tensorflow as tf

import os ,sys, platform
import time
import cosmopower as cp
import multiprocessing
from multiprocessing import Pool
import threading

#Planks Values
el = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 0, skiprows=1,dtype =float)
el_te = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 0, skiprows=1,dtype =float)
Dl_TT = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_TT_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_TT_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-TT-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
Dl_EE = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_EE_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_EE_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-EE-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
Dl_TE = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 1, skiprows=1,dtype =float)
Dl_TE_err_up = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 3, skiprows=1,dtype =float)
Dl_TE_err_bot = np.loadtxt('planks/COM_PowerSpect_CMB-TE-full_R3.01.txt',usecols = 2, skiprows=1,dtype =float)
#ells
dl_fac = el*(el+1)/(2*np.pi)
dl_fac_te = el_te*(el_te+1)/(2*np.pi)
#COSMOPOWER
tt_emu = cp.cosmopower_NN(restore=True,restore_filename='COSMO/cmb_TT_NN')
ee_emu = cp.cosmopower_NN(restore=True,restore_filename='COSMO/cmb_EE_NN')
te_emu = cp.cosmopower_PCAplusNN(restore=True,restore_filename='COSMO/cmb_TE_PCAplusNN')

def Cosmo(xe,ze): # function for Cosmopower
    if xe == 'TT':
        tt_spectra = tt_emu.ten_to_predictions_np(ze)
        CO = tt_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
    elif xe == 'EE':
        ee_spectra = ee_emu.ten_to_predictions_np(ze)
        CA = ee_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
        CO = CA[:1995] #since planks data as only 1995 values 
    elif xe == 'TE':
        te_spectra = te_emu.predictions_np(ze)
        CA = te_spectra[0]*1e12 * 2.73**2. #K^2 to uK^2
        CO = CA[:1995] #since planks data as only 1995 values 
    else:
        Print('Check Input Range or Data')
    return CO

def Camb_pp(ell,ell_max,parameter,x,lens_accuracy=0): #Function for CAMb
    #camb model pars
    pars = camb.CAMBparams()
    pars.set_cosmology(H0 = par["H0"], ombh2=par["ombh2"], omch2=par["omch2"], mnu=par["mnu"], omk=par["omk"], tau=par["tau"])
    pars.InitPower.set_params(As=par["As"], ns=par["ns"], r=par["r"])
    pars.set_for_lmax(ell_max-1, lens_potential_accuracy=float(lens_accuracy));
    #camb result and power spectra
    camb_results = camb.get_results(pars)
    powers = camb_results.get_cmb_power_spectra(pars, CMB_unit="muK")#,raw_cl=True)
    
    if x == 'TT':
        #CAMB TT
        cambq = powers['lensed_scalar'][:, 0][2:ell_max]
    elif x == 'EE':
        #CAMB EE
        cambq = powers['lensed_scalar'][:, 1][2:ell_max]
    elif x == 'TE':
        #CAMB TE
        cambq = powers['lensed_scalar'][:, 3][2:ell_max]
    else:
        #CAMB TE EE
        cambq = None  
    return cambq 

def chi2(tre,teu,trb,pred): #chi^2 model
    #c = ((tre - pred)**2)/((pred)**2)
    c = ((tre - pred)**2)/((teu + trb)**2) # (Real - Model)^2/(Error Up + Error Bottom)^2
    chi = np.sum(c)
    return chi

#time ms to order of time
def time_hr(ms):
    ssm = ms*100
    seconds = int(ssm/100)
    minutes = int(seconds/60)
    hours = int(minutes/60)
    days = int(hours/24)
    sm = int(ssm - seconds*100)
    s = seconds - minutes*60 
    m = minutes - hours*60
    h = hours - days*24
    t = [sm,s,m,h,days]
    xi = ''
    if days == h == m == s == 0 :
        xi = str(sm) +'ms '
    elif days == h == m == 0:
        xi = str(s) +'s ' + str(sm) +' ms'
    elif days == h == 0:
        xi = str(m) + ' min ' + str(s) +'s ' + str(sm) +' ms'
    elif days == 0:
        xi = str(h) + 'hrs '+str(m) + 'min '+str(s) +'s ' + str(sm) +' ms'
    else :
        xi = str(days) +'days ' + str(h) + 'hrs '+str(m) + 'min '+str(s) +'s ' + str(sm) +' ms' 
    return xi

def Cosmo_Power(DET,omb,omc,h,tau,ns,As): #function for single value cosmopower
   
    params = {'omega_b': [omb],'omega_cdm': [omc],'h': [h/100],'tau_reio': [tau],'n_s': [ns],'ln10^{10}A_s': [np.log( 10**10 *(As*1e-9) )],}
    Para = [omb,omc,h,tau,ns,As]
    if DET=='TT':
        pred = Cosmo('TT',params)*dl_fac
        chi = chi2(Dl_TT*dl_fac,Dl_TT_err_up*dl_fac,Dl_TT_err_bot*dl_fac,pred*dl_fac)
    elif DET=='TE':
        pred = Cosmo('TE',params)*dl_fac_te
        chi = chi2(Dl_TE,Dl_TE_err_up,Dl_TE_err_bot,pred)
    elif DET=='EE':
        pred = Cosmo('EE',params)*dl_fac_te
        chi = chi2(Dl_EE,Dl_EE_err_up,Dl_EE_err_bot,pred)
    return Para,pred,chi #parameter, prediction , chi value

def Find_val(inputrange,array):
    #finding the input value for the  minimum chi2 value
    min_chi2 = np.argmin(array) #position of minimum chi2
    vals = inputrange[min_chi2] #finding Input value of minimum chi2
    return vals

def for_cosmo(DET,DEF,range,para):
    #finding the fitted value for single values
    pred_arr=[]
    chi_arr=[]
    if DEF=='omb':
        for val in range:
            des = Cosmo_Power(DET,val,para[1],para[2],para[3],para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])            
    elif DEF=='omc':
        for val in range:
            des = Cosmo_Power(DET,para[0],val,para[2],para[3],para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='h':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],val,para[3],para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='tau':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],para[2],val,para[4],para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='ns':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],para[2],para[3],val,para[5])
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    elif DEF=='as':
        for val in range:
            des = Cosmo_Power(DET,para[0],para[1],para[2],para[3],para[4],val)
            pred_arr.append(des[1])
            chi_arr.append(des[2])
    else:
        Print("check DATA type. ERROR!")
        
    fitted_val = Find_val(range,chi_arr)
    return fitted_val #returns best fitted value with chi2

def iter_pars(DET,rang,para):
    #function to iterate each parameters by setting all initial parameter and runnning each time and setting the parameter
    omb = for_cosmo(DET,'omb',rang[0],para)
    para[0] = omb
    omc = for_cosmo(DET,'omc',rang[1],para)
    para[1] = omc
    h = for_cosmo(DET,'h',rang[2],para)
    para[2] = h
    tau = for_cosmo(DET,'tau',rang[3],para)
    para[3] = tau
    ns = for_cosmo(DET,'ns',rang[4],para)
    para[4] = ns
    As = for_cosmo(DET,'as',rang[5],para)
    para[5] = As
    para = [omb,omc,h,tau,ns,As]
    return para # return parameter
    
def loop_it(DET,rang,paras,tims):
    #this function finding parameters for several 'times', finding errors for each parameters
    omb = []
    omc = []
    h = []
    tau = []
    ns = []
    As = []
    for i in range(tims):
        para = iter_pars(DET,rang,paras)
        omb.append(para[0])
        omc.append(para[1])
        h.append(para[2])
        tau.append(para[3])
        ns.append(para[4])
        As.append(para[5])

    omb_error = np.std(omb)
    omc_error = np.std(omc)
    h_error = np.std(h)
    tau_error = np.std(tau)
    ns_error = np.std(ns)
    As_error = np.std(As)
    para_error = [omb_error,omc_error,h_error,tau_error,ns_error,As_error ]
    para = [np.average(omb),np.average(omc),np.average(h),np.average(tau),np.average(ns),np.average(As)]
    #returning prameters and its errors which is standard deviations
    return para,para_error

#double parameters functions
def cosmopo(DET,par_arr,da='none',db='none'): #cosmopower for a array of values
    pre = []
    chi = []
    arr = []
    for par in par_arr: #iterating each parameters in the array
        set =  Cosmo_Power(DET,par[0],par[1],par[2],par[3],par[4],par[5])
        set_pre = set[1]
        set_chi = set[2]
        pre.append(set_pre)
        chi.append(set_chi)
        arr.append([par[0],par[1],par[2],par[3],par[4],par[5],da,db,set_chi])
    fit_par = Find_val(par_arr,chi) #finding the best fitted parameters from the array
    return fit_par,arr

def par_arr(DEF,rang,par): #for creating array of parameters for one set of range
    arr = []
    for i in rang:
        if DEF == 'omb':
            arr.append([i,par[1],par[2],par[3],par[4],par[5]])
        elif DEF == 'omc':
            arr.append([par[0],i,par[2],par[3],par[4],par[5]])
        elif DEF == 'h':
            arr.append([par[0],par[1],i,par[3],par[4],par[5]])
        elif DEF == 'tau':
            arr.append([par[0],par[1],par[2],i,par[4],par[5]])
        elif DEF == 'ns':
            arr.append([par[0],par[1],par[2],par[3],i,par[5]])
        elif DEF == 'as':
            arr.append([par[0],par[1],par[2],par[3],par[4],i])
        else :
            print('check input par')

    return arr #returns only a arrray

def par_arr_2(DEF1,DEF2,rang1,rang2,par): #creating array of parameters for 2 sets of ranges
    arr = []
    first_arr = par_arr(DEF1,rang1,par)#initial single array creation
    for i in first_arr: 
        for j in rang2:
            if DEF2 == 'omb':
                arr.append([j,i[1],i[2],i[3],i[4],i[5]])
            elif DEF2 == 'omc':
                arr.append([i[0],j,i[2],i[3],i[4],i[5]])
            elif DEF2 == 'h':
                arr.append([i[0],i[1],j,i[3],i[4],i[5]])
            elif DEF2 == 'tau':
                arr.append([i[0],i[1],i[2],j,i[4],i[5]])
            elif DEF2 == 'ns':
                arr.append([i[0],i[1],i[2],i[3],j,i[5]])
            elif DEF2 == 'as':
                arr.append([i[0],i[1],i[2],i[3],i[4],j])
            else:
                print("check")

    return arr,DEF1,DEF2 #returns the array rang1*rang2 and parameter1 and 2

def cospor(DET,i,pars_arr,ran_arr,par,ret_arr=False): #for simple Calculation inputs are Data type,iteration number,parameter name array, range array,parameter
    pars = ["omb","omc","h","tau","ns","as"]
    da = pars_arr[i][0] #getting parameter name 1
    db = pars_arr[i][1] #getting parameter name 2
    Ra1 = ran_arr[pars.index(da)] # range of parameter1 
    Ra2 = ran_arr[pars.index(db)] # range of parameter2
    arr = par_arr_2(da,db,Ra1,Ra2,par)[0] #array generation 
    parm = cosmopo(DET,arr,da,db) #Cosmopowers on array
    arr = parm[1]
    rev = [parm[0],da,db] #fitted parameters for given range i
    np.save('likeliyhood/chi_arr/'+da+'_'+db,parm[1])
    if ret_arr==True:
        return rev,arr
    else:
        return rev

def cospors(rang_arr,par,par_arr = None,plot = False,thread = False):
    pars = ["omb","omc","h","tau","ns","as"]
    pars_arr = []
    #array generation with parameters names it also as rules that [a,a] does not exist,[a,b] or [a,b] pairs repeat once
    if par_arr == None:
        for xi in pars:
            for yi in pars:
                if xi == yi:
                    pass
                else:
                    pars_arr.append([xi,yi])

        for xi in pars:
            for yi in pars:
                for ys in pars_arr:
                    if [xi,yi]==ys:
                        pars_arr.remove([yi,xi])
                    else:
                        pass
    else:
        pars_arr = par_arr
        
    threads = [] #multithreading for fast calculations
    par_ar = [] 
    par_a = []#this is the results parameters stored

    for i in range(len(pars_arr)): # number of calculations
        if thread == False: #Direct calculations without threading
            par_a.append(cospor('TT',i,pars_arr,rang_arr,par)) #value stored as[[parameters],name of par1,2]
        else:
            t = threading.Thread(target=lambda i=i: par_ar.append(cospor("TT",i,pars_arr,rang_arr,par,True))) #multithreading parameters
            threads.append(t) #saving the threads
            t.start() #start threads  
            
            for t in threads: # for join threads at closing
                t.join() # on joining no threads is in order

    print_arr = []
    plot_arr = []
    if thread == True:
        for i in par_ar:
            par_a.append(i[0])
            plot_arr.append(i[1])

    if plot == True:
        for i in plot_arr:
            arrar = []
            xy = []
            yy = []
            z = []
            da = i[0][6]
            db = i[0][7]
            for j in i:
                da = j[6]
                db = j[7]
                chi = j[8]
                xi = j[pars.index(da)]
                yi = j[pars.index(db)]
                arrar.append([xi,yi,chi])
            print_arr.append([da,db,arrar])
            np.save('likeliyhood/comparison/plot_arr/'+da+'_'+db,arrar)
            plotif(arrar,da,db)
        
    runs =[par_a , print_arr]
    return runs#[[parameters],name of parameter1 and parameter2] in a list

def de_par(par_aa,prints=False): #for finding average and standard deviation of given parameters
    pars = ["omb","omc","h","tau","ns","as"]
    par = [[],[],[],[],[],[]]
    for i in par_aa:
        par[pars.index(i[1])].append(i[0][pars.index(i[1])])
        par[pars.index(i[2])].append(i[0][pars.index(i[2])])
    pam = [[],[],[],[],[],[]]
    rev =[]
    for i in range(len(pars)):
        pam[i].append([pars[i],[np.average(par[i])],[np.std(par[i])]])
    
    for i in pam:
        if prints == True:
            print(i[0][0],':',np.round(i[0][1],5),'+-',np.round(i[0][2],10))
        else:
            rev.append([i[0][0],':',np.round(i[0][1],5),'+-',np.round(i[0][2],10)])    
    return rev #list(parameters:value +- standard deviation)

def plotif(arri,da,db,drae = False):
    d = [[],[],[]]
    for j in range(len(arri)):
        d[0].append(arri[j][0])
        d[1].append(arri[j][1])
        d[2].append(arri[j][2])

    e = [np.unique(d[0]),np.unique(d[1]),np.rot90(np.reshape(d[2],(np.shape(np.unique(d[0]))[0],np.shape(np.unique(d[1]))[0])))]
    extent = (np.min(e[0]),np.max(e[0]),np.min(e[1]),np.max(e[1]))
    f = np.log(e[2])
    dd =[da,db]
    if drae ==False:
        par_1 = e[0][np.argmin(np.nanmean(f,axis = 0))]
        par_2 = e[1][np.argmin(np.nanmean(f,axis = 1))]
        plt.axhline(par_1)
        plt.axvline(par_2)
        plt.xlabel(da)
        plt.ylabel(db)
        plt.imshow(f,aspect='auto',cmap=plt.cm.Spectral,extent= extent)
        plt.colorbar()
        plt.show()
    else: 
        fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12,4))
        '''deltachi_1 = np.max(e[2]) - 2*np.log(np.mean(e[2],axis=0))
        deltachi_2 = np.max(e[2]) - 2*np.log(np.mean(e[2],axis=1))
        '''
        #plt.plot(e[1],np.log(np.mean(e[2],axis=1)),xlabel=db,ylabel='chi_sq')
    
        deltachi_1=np.log(np.mean(e[2],axis=0))/np.min(np.log(np.mean(e[2],axis=0)))
        deltachi_2=np.log(np.mean(e[2],axis=1))/np.min(np.log(np.mean(e[2],axis=1)))
        ax1.plot(e[0],deltachi_1)
        ax1.set_xlabel(dd[0])
        ax2.set_xlabel(dd[1])
        ax1.set_ylabel('chi_sq')
        ax2.set_ylabel('chi_sq')
        

        ax2.plot(e[1],deltachi_2)
        plt.show()
        print('Resulted Values')
        for i in range(2):

            s = np.mean(e[2],axis=i)/np.min(np.mean(e[2],axis=i))
            eff = 1.01
            es = []
            ess = []
            for l in range(len(e[i])):
                if s[l] > eff:
                    es.append(0)
                elif s[l] <= eff:
                    es.append(e[i][l])
                    ess.append(e[i][l])
            er = [np.min(ess),np.average(ess),np.max(ess)]
            error = np.std(er)

            
            print(dd[i],':',d[i][np.argmin(np.mean(e[2],axis=i))],'+_',error)
        
    return e

def Cosmo_Powerq(omb,omc,h,tau,ns,As): #function for single value cosmopower
    DET = 'TT'
    params = {'omega_b': [omb],'omega_cdm': [omc],'h': [h/100],'tau_reio': [tau],'n_s': [ns],'ln10^{10}A_s': [np.log( 10**10 *(As*1e-9) )],}
    Para = [omb,omc,h,tau,ns,As]
    if DET=='TT':
        pred = Cosmo('TT',params)*dl_fac
        chi = chi2(Dl_TT*dl_fac,Dl_TT_err_up*dl_fac,Dl_TT_err_bot*dl_fac,pred*dl_fac)
    elif DET=='TE':
        pred = Cosmo('TE',params)*dl_fac_te
        chi = chi2(Dl_TE,Dl_TE_err_up,Dl_TE_err_bot,pred)
    elif DET=='EE':
        pred = Cosmo('EE',params)*dl_fac_te
        chi = chi2(Dl_EE,Dl_EE_err_up,Dl_EE_err_bot,pred)
    reference = [omb,omc,h,tau,ns,As,chi]
    return chi #parameter, prediction , chi value
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %% [markdown]
# <h1>Code for 1 parameter</h1>

# %% [markdown]
# <h3>Normal</h3>

# %%
arr = [[0.001,0.08],[0.01,0.3],[67,68],[0.05,0.06],[0.9,1],[2,2.2]]

# %%
#print(Cosmo_Power('EE',0.0221,0.1205,67.29,0.0542,0.945,2.0969)[1])
omb = np.arange(arr[0][0],arr[0][1],0.00001)
omc = np.arange(arr[1][0],arr[1][1],0.0001)
h = np.arange(arr[2][0],arr[2][1],0.01)
tau = np.arange(arr[3][0],arr[3][1],0.00001)
ns = np.arange(arr[4][0],arr[4][1],0.001)
As = np.arange(arr[5][0],arr[5][1],0.0001)
rangee = [omb,omc,h,tau,ns,As]
paras = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
start_time = time.time() #time calculation
p_TT = loop_it('TT',rangee,paras,4) # direct calculations

for x in range(6):
    print(p_TT[0][x],'+-',p_TT[1][x])# looping for print
    
end_time = time.time() #time calculation
tim = time_hr(end_time - start_time) # finding time for excution
print( 'Executed in :',tim)
# Out:
# 0.022272500000000056 +- 0.00019841559918514526
# 0.12052499999999933 +- 0.00030310889132455107
# 67.25500000000014 +- 0.032787192621526774
# 0.05019750000000006 +- 0.00034208003449495803
# 0.9637500000000001 +- 0.004968651728587952
# 2.0809000000001707 +- 0.003025723054087839
# Executed in : 4 min 55s 48 ms

# %% [markdown]
# <h3>Cobaya For 1 paramter</h3>

# %%
def cobaya_1(arr,DET):

    if DET == 'omb':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Powerq(Dpar,0.1208,67.29,0.0542,0.945,2.0969)))
    elif DET == 'omc':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Powerq(0.0228,Dpar,67.29,0.0542,0.945,2.0969)))
    elif DET == 'h':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Powerq(0.0228,0.1208,Dpar,0.0542,0.945,2.0969)))
    elif DET == 'tau':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Powerq(0.0228,0.1208,67.29,Dpar,0.945,2.0969)))
    elif DET == 'ns':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Powerq(0.0228,0.1208,67.29,0.0542,Dpar,2.0969)))
    elif DET == 'AS':
        def cobaya_com(Dpar):
            return (10 - np.log(Cosmo_Powerq(0.0228,0.1208,67.29,0.0542,0.945,Dpar)))
    # below is parameters for 6 parameter cosmopower
    info = {"likelihood": {"cosmo": cobaya_com}}
    info["params"] = {
        "Dpar": {"prior": {"min": arr[0], "max": arr[1]}, "ref": arr[2], "proposal": 0.001},}
    info["sampler"] = {"mcmc": {"Rminus1_stop": 0.0001, "max_tries": 1000}}

    from cobaya import run
    updated_info, sampler = run(info)

    import getdist.plots as gdplt

    gdsamples = sampler.products(to_getdist=True)["sample"]
    ser = gdsamples.samples[np.argmin(gdsamples.loglikes)][0]

    return ser

# %%
df = []
for i in range(6):
    par = ["omb","omc","h","tau","ns","AS"]
    pare = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
    se = cobaya_1([arr[i][0],arr[i][1],pare[i]],par[i])
    df.append(se)
# Out:
# [cosmo] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: Dpar:0.0228
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {cosmo: 214.0}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-02-28 17:35:12 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 40 samples accepted.
# [mcmc]  - Acceptance rate: 0.970
# [mcmc]  - Convergence of means: R-1 = 7.950247 after 32 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# D:\Python\project_cosmology\cospo\lib\site-packages\cobaya\collection.py:651: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._data = pd.concat([
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.865
# [mcmc]  - Convergence of means: R-1 = 1.132695 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 120 samples accepted.
# [mcmc]  - Acceptance rate: 0.662
# [mcmc]  - Convergence of means: R-1 = 0.118384 after 96 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.598
# [mcmc]  - Convergence of means: R-1 = 0.230472 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 200 samples accepted.
# [mcmc]  - Acceptance rate: 0.468
# [mcmc]  - Convergence of means: R-1 = 0.152175 after 160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.433
# [mcmc]  - Convergence of means: R-1 = 0.179542 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 280 samples accepted.
# [mcmc]  - Acceptance rate: 0.405
# [mcmc]  - Convergence of means: R-1 = 0.122144 after 224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.394
# [mcmc]  - Convergence of means: R-1 = 0.111677 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 360 samples accepted.
# [mcmc]  - Acceptance rate: 0.375
# [mcmc]  - Convergence of means: R-1 = 0.060208 after 288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.375
# [mcmc]  - Convergence of means: R-1 = 0.041483 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 440 samples accepted.
# [mcmc]  - Acceptance rate: 0.369
# [mcmc]  - Convergence of means: R-1 = 0.029895 after 352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.362
# [mcmc]  - Convergence of means: R-1 = 0.056170 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 520 samples accepted.
# [mcmc]  - Acceptance rate: 0.349
# [mcmc]  - Convergence of means: R-1 = 0.060188 after 416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.334
# [mcmc]  - Convergence of means: R-1 = 0.043576 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 600 samples accepted.
# [mcmc]  - Acceptance rate: 0.335
# [mcmc]  - Convergence of means: R-1 = 0.021317 after 480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.001568 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 680 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.025668 after 544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.015580 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 760 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.014686 after 608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.013529 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 840 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.002545 after 672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.002210 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 920 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.007999 after 736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.333
# [mcmc]  - Convergence of means: R-1 = 0.005882 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1000 samples accepted.
# [mcmc]  - Acceptance rate: 0.334
# [mcmc]  - Convergence of means: R-1 = 0.003948 after 800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.336
# [mcmc]  - Convergence of means: R-1 = 0.007842 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1080 samples accepted.
# [mcmc]  - Acceptance rate: 0.339
# [mcmc]  - Convergence of means: R-1 = 0.013814 after 864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.340
# [mcmc]  - Convergence of means: R-1 = 0.018130 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1160 samples accepted.
# [mcmc]  - Acceptance rate: 0.338
# [mcmc]  - Convergence of means: R-1 = 0.007616 after 928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.331
# [mcmc]  - Convergence of means: R-1 = 0.000835 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1240 samples accepted.
# [mcmc]  - Acceptance rate: 0.332
# [mcmc]  - Convergence of means: R-1 = 0.000942 after 992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.332
# [mcmc]  - Convergence of means: R-1 = 0.002961 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1320 samples accepted.
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.002664 after 1056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.010923 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1400 samples accepted.
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.008350 after 1120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.332
# [mcmc]  - Convergence of means: R-1 = 0.009282 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1480 samples accepted.
# [mcmc]  - Acceptance rate: 0.332
# [mcmc]  - Convergence of means: R-1 = 0.021280 after 1184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.333
# [mcmc]  - Convergence of means: R-1 = 0.037201 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1560 samples accepted.
# [mcmc]  - Acceptance rate: 0.330
# [mcmc]  - Convergence of means: R-1 = 0.022022 after 1248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.329
# [mcmc]  - Convergence of means: R-1 = 0.014327 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1640 samples accepted.
# [mcmc]  - Acceptance rate: 0.329
# [mcmc]  - Convergence of means: R-1 = 0.019261 after 1312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.008877 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1720 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.005620 after 1376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.004320 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1800 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.002010 after 1440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.004476 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1880 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.015640 after 1504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.015870 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1960 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.014764 after 1568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.015412 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2040 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.018399 after 1632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.012371 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2120 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.008959 after 1696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.008836 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2200 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.010056 after 1760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.008618 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2280 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.007156 after 1824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.006094 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2360 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.006433 after 1888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.003499 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2440 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.005236 after 1952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.006355 after 1984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2520 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.012351 after 2016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.011008 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2600 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.009006 after 2080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.005935 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2680 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.006214 after 2144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.328
# [mcmc]  - Convergence of means: R-1 = 0.002359 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2760 samples accepted.
# [mcmc]  - Acceptance rate: 0.329
# [mcmc]  - Convergence of means: R-1 = 0.001941 after 2208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2800 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.001850 after 2240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2840 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.002561 after 2272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.001562 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2920 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.002086 after 2336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2960 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.003425 after 2368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3000 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.003212 after 2400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.003752 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3080 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.001741 after 2464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.001119 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3160 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.001462 after 2528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.000703 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3240 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.001079 after 2592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3280 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.001807 after 2624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3320 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.002649 after 2656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.003991 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3400 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.004652 after 2720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3440 samples accepted.
# [mcmc]  - Acceptance rate: 0.326
# [mcmc]  - Convergence of means: R-1 = 0.003317 after 2752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3480 samples accepted.
# [mcmc]  - Acceptance rate: 0.327
# [mcmc]  - Convergence of means: R-1 = 0.005608 after 2784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.324
# [mcmc]  - Convergence of means: R-1 = 0.005334 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3560 samples accepted.
# [mcmc]  - Acceptance rate: 0.325
# [mcmc]  - Convergence of means: R-1 = 0.007026 after 2848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.003686 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3640 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.002593 after 2912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.002484 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3720 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.003094 after 2976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3760 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.003632 after 3008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3800 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.003859 after 3040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.002886 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3880 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.002931 after 3104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3920 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001748 after 3136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3960 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.002036 after 3168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.002945 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4040 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.002642 after 3232 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.004091 after 3264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4120 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.005126 after 3296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.004361 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4200 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.003858 after 3360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4240 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.004521 after 3392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4280 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.005838 after 3424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.005056 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4360 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.003864 after 3488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4400 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001883 after 3520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4440 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.002327 after 3552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001041 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4520 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001190 after 3616 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4560 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000662 after 3648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4600 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000429 after 3680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000727 after 3712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4680 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001379 after 3744 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4720 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000761 after 3776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4760 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001222 after 3808 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001065 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4840 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000595 after 3872 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4880 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000303 after 3904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4920 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000920 after 3936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4960 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000769 after 3968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5000 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001865 after 4000 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5040 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.002018 after 4032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5080 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.002903 after 4064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5120 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.003191 after 4096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5160 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.003078 after 4128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5200 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.003362 after 4160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-28 17:36:12 : 15965 steps taken, and 5237 accepted.
# [mcmc] Learn + convergence test @ 5240 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.003691 after 4192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.003138 after 4224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5320 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.002705 after 4256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5360 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.002963 after 4288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5400 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.002072 after 4320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5440 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001286 after 4352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5480 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000968 after 4384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5520 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.001090 after 4416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5560 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.001402 after 4448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5600 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000544 after 4480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5640 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000646 after 4512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5680 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001255 after 4544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5720 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000926 after 4576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001191 after 4608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5800 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001644 after 4640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5840 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001580 after 4672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5880 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001738 after 4704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5920 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001413 after 4736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5960 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.001566 after 4768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6000 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.001382 after 4800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6040 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001648 after 4832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6080 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001076 after 4864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6120 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001182 after 4896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6160 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001674 after 4928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6200 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001350 after 4960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6240 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.001013 after 4992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6280 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000470 after 5024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6320 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000494 after 5056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6360 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000539 after 5088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6400 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000472 after 5120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6440 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000318 after 5152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6480 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000618 after 5184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6520 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000682 after 5216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6560 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000915 after 5248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6600 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000593 after 5280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6640 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000812 after 5312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6680 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000965 after 5344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6720 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000956 after 5376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6760 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001096 after 5408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6800 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001239 after 5440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6840 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.002051 after 5472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6880 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.001588 after 5504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6920 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.001195 after 5536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6960 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001150 after 5568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7000 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001599 after 5600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7040 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001986 after 5632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7080 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001436 after 5664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7120 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001796 after 5696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7160 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.001576 after 5728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7200 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.001648 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7240 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.001082 after 5792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7280 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.000707 after 5824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7320 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000522 after 5856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7360 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000442 after 5888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7400 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000495 after 5920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7440 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000654 after 5952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7480 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.000495 after 5984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7520 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.000487 after 6016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7560 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.000422 after 6048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7600 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.000399 after 6080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7640 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000679 after 6112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7680 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000614 after 6144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7720 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000320 after 6176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7760 samples accepted.
# [mcmc]  - Acceptance rate: 0.318
# [mcmc]  - Convergence of means: R-1 = 0.000248 after 6208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7800 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000233 after 6240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7840 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000280 after 6272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7880 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000164 after 6304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7920 samples accepted.
# [mcmc]  - Acceptance rate: 0.319
# [mcmc]  - Convergence of means: R-1 = 0.000142 after 6336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7960 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000230 after 6368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8000 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000269 after 6400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8040 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000354 after 6432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8080 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000521 after 6464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8120 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000604 after 6496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8160 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000453 after 6528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8200 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.001129 after 6560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8240 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.001171 after 6592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8280 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.000862 after 6624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8320 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.001030 after 6656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8360 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000801 after 6688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8400 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000650 after 6720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8440 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000573 after 6752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8480 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000678 after 6784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8520 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000775 after 6816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8560 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000599 after 6848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8600 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.000680 after 6880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8640 samples accepted.
# [mcmc]  - Acceptance rate: 0.323
# [mcmc]  - Convergence of means: R-1 = 0.000770 after 6912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8680 samples accepted.
# [mcmc]  - Acceptance rate: 0.322
# [mcmc]  - Convergence of means: R-1 = 0.000625 after 6944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8720 samples accepted.
# [mcmc]  - Acceptance rate: 0.321
# [mcmc]  - Convergence of means: R-1 = 0.000754 after 6976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# ...
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17720 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000796 after 14176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17760 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000976 after 14208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17800 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.001146 after 14240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17840 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.001081 after 14272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17880 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.001097 after 14304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17920 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000872 after 14336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17960 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000668 after 14368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18000 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000760 after 14400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18040 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000720 after 14432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18080 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000868 after 14464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18120 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000960 after 14496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18160 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000989 after 14528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18200 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.000773 after 14560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18240 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.000836 after 14592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18280 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.000592 after 14624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18320 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.000571 after 14656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18360 samples accepted.
# [mcmc]  - Acceptance rate: 0.474
# [mcmc]  - Convergence of means: R-1 = 0.000552 after 14688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18400 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000512 after 14720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18440 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000428 after 14752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18480 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000297 after 14784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18520 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000361 after 14816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18560 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000427 after 14848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18600 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000419 after 14880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18640 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000475 after 14912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18680 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000379 after 14944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18720 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000359 after 14976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18760 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000371 after 15008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18800 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000277 after 15040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18840 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000316 after 15072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18880 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000208 after 15104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18920 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000166 after 15136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18960 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000208 after 15168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19000 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000194 after 15200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19040 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000173 after 15232 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19080 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000243 after 15264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19120 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000307 after 15296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19160 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000324 after 15328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19200 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000318 after 15360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19240 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000340 after 15392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19280 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000297 after 15424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19320 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000349 after 15456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19360 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000297 after 15488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19400 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000232 after 15520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19440 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000173 after 15552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19480 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000185 after 15584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19520 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000151 after 15616 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19560 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000190 after 15648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19600 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000178 after 15680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19640 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000183 after 15712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19680 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000168 after 15744 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19720 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000269 after 15776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19760 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000263 after 15808 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19800 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000172 after 15840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19840 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000256 after 15872 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19880 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000211 after 15904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19920 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000232 after 15936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 19960 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000254 after 15968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20000 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000254 after 16000 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20040 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000242 after 16032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20080 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000308 after 16064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20120 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000225 after 16096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20160 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000140 after 16128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20200 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000079 after 16160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20240 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000115 after 16192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20280 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000197 after 16224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20320 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000228 after 16256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20360 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000230 after 16288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20400 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000204 after 16320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20440 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000165 after 16352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20480 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000119 after 16384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20520 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000043 after 16416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 20560 samples accepted.
# [mcmc]  - Acceptance rate: 0.475
# [mcmc]  - Convergence of means: R-1 = 0.000012 after 16448 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.007781 after 20560 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 20560 accepted steps.
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'

# %%
print(df)
# Out:
# [0.022613494451962195, 0.12044951933427334, 67.21020078879239, 0.05000007011912052, 0.9633549620182229, 2.1146039614440904]

# %% [markdown]
# <h2>On Comparing</h2>
#
# <table>
#     <tr>
#         <th>Parameter</th>
#         <th>Single Parameter</th>
#         <th>Cobaya Parameter</th>
#         <th>Error</th>
#     </tr>
#     <tr>
#         <th>OMB</th>
#         <td>0.0222724</td>
#         <td>0.02261203</td>
#         <td>0.000198415</td>
#     </tr>
#     <tr>
#         <th>OMC</th>
#         <td>0.120525</td>
#         <td>0.12045</td>
#         <td>0.000303108</td>
#      </tr>
#      <tr>
#         <th>H</th>
#         <td>67.255</td>
#         <td>67.2088</td>
#          <td>0.0327871</td>
#      </tr>
#      <tr>
#         <th>TAU</th>
#         <td>0.050197</td>
#         <td>0.0500</td>
#          <td>0.00034208</td>
#     </tr>
#     <tr>
#         <th>NS</th>
#         <td>0.963750</td>
#         <td>0.9633696</td>
#         <td> 0.004968</td>
#     </tr>
#     <tr>
#         <th>AS</th>
#         <td>2.0809</td>
#         <td>2.1146</td>
#         <td>0.003025723</td>
#      </tr>
# </table>

# %% [markdown]
# <h1>Comparee 2 parameter</h1>

# %%
0.022272500000000056 +- 0.00019841559918514526
0.12052499999999933 +- 0.00030310889132455107
67.25500000000014 +- 0.032787192621526774
0.05019750000000006 +- 0.00034208003449495803
0.9637500000000001 +- 0.004968651728587952
2.0809000000001707 +- 0.003025723054087839

[0.022613494451962195, 0.12044951933427334, 67.21020078879239, 0.05000007011912052, 0.9633549620182229, 2.1146039614440904]

# %%
#Double parameter method
#print(Cosmo_Power('EE',0.0221,0.1205,67.29,0.0542,0.945,2.0969)[1])
omb = np.arange(arr[0][0],arr[0][1],0.00001)
omc = np.arange(arr[1][0],arr[1][1],0.0001)
h = np.arange(arr[2][0],arr[2][1],0.01)
tau = np.arange(arr[3][0],arr[3][1],0.00001)
ns = np.arange(arr[4][0],arr[4][1],0.001)
As = np.arange(arr[5][0],arr[5][1],0.0001)
rangee = [omb,omc,h,tau,ns,As]

paras = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
st = time.time()
pars_aray = [['omc','omb'],
             ['h','omb'],  ['h','omc'],['ns','tau'],['as','tau'],
             ['tau','omb'],['tau','omc'],
             ['ns','omb'], ['ns','omc'], ['ns','h'], ['ns','tau'],
             ['as','omb'], ['as','omc'], ['as','h'], ['as','tau'],['as','ns']]
par_ar1 = cospors(rangee,paras,pars_aray,True,True)
print('completed in ',time_hr(time.time()-st),':',par_ar1[0])
et = time.time()
print('Total Time Taken : ',time_hr(et-st))

# %%
r=["omb","omc","h","tau","ns","as"]
s= [['omc','omb'],['h','omb'],  ['h','omc'],['ns','tau'],['as','tau'],
             ['tau','omb'],['tau','omc'],
             ['ns','omb'], ['ns','omc'], ['ns','h'], ['ns','tau'],
             ['as','omb'], ['as','omc'], ['as','h'], ['as','tau'],['as','ns']]
for i in s:
    print("    elif DET == '",i[0],"' and DET2 == '",i[1],"':")
    print("        def cobaya_com(Dpar,Spar):")
    t = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
    t[r.index(i[0])] = 'Dpar'
    t[r.index(i[1])] = 'Spar'
    print("            return (10 - np.log(Cosmo_Powerq(",t,")))")

# %%
def cobaya_2(arr,DET,DET2):
    if DET == 'omc' and DET2 == 'omb':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( Spar, Dpar, 67.29, 0.0542, 0.945, 2.0969 )))
    elif DET == 'h' and DET2 == 'omb':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( Spar, 0.1208, Dpar, 0.0542, 0.945, 2.0969)))
    elif DET == 'h' and DET2 == 'omc':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, Spar, Dpar, 0.0542, 0.945, 2.0969)))
    elif DET == 'ns' and DET2 == 'tau':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, 67.29, Spar, Dpar, 2.0969 )))
    elif DET == 'as' and DET2 == 'tau':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, 67.29, Spar, 0.945, Dpar )))
    elif DET == 'tau' and DET2 == 'omb':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( Spar, 0.1208, 67.29, Dpar, 0.945, 2.0969 )))
    elif DET == 'tau' and DET2 == 'omc':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, Spar, 67.29, Dpar, 0.945, 2.0969 )))
    elif DET == 'ns' and DET2 == 'omb':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( Spar, 0.1208, 67.29, 0.0542, Dpar, 2.0969 )))
    elif DET == 'ns' and DET2 == 'omc':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, Spar, 67.29, 0.0542, Dpar, 2.0969 )))
    elif DET == 'ns' and DET2 == 'h':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, Spar, 0.0542, Dpar, 2.0969 )))
    elif DET == 'ns' and DET2 == ' tau ':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, 67.29, Spar, Dpar, 2.0969 )))
    elif DET == 'as' and DET2 == 'omb':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( Spar, 0.1208, 67.29, 0.0542, 0.945, Dpar )))
    elif DET == 'as' and DET2 == 'omc':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, Spar, 67.29, 0.0542, 0.945, Dpar )))
    elif DET == 'as' and DET2 == 'h':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, Spar, 0.0542, 0.945, Dpar )))
    elif DET == ' as ' and DET2 == 'tau':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, 67.29, Spar, 0.945, Dpar )))
    elif DET == 'as' and DET2 == 'ns':
        def cobaya_com(Dpar,Spar):
            return (10 - np.log(Cosmo_Powerq( 0.0228, 0.1208, 67.29, 0.0542, Spar, Dpar )))
    else:
        print('error')
    # below is parameters for 6 parameter cosmopower
    info = {"likelihood": {"cosmo": cobaya_com}}
    info["params"] = {
        "Dpar": {"prior": {"min": arr[0][0], "max": arr[0][1]}, "ref": arr[0][2], "proposal": 0.001},
        "Spar": {"prior": {"min": arr[1][0], "max": arr[1][1]}, "ref": arr[1][2], "proposal": 0.001},}
    info["sampler"] = {"mcmc": {"Rminus1_stop": 0.001, "max_tries": 1000}}

    from cobaya import run
    updated_info, sampler = run(info)

    import getdist.plots as gdplt

    gdsamples = sampler.products(to_getdist=True)["sample"]
    ser = gdsamples.samples[np.argmin(gdsamples.loglikes)]


    return [ser[0],ser[1]]

# %%
r=["omb","omc","h","tau","ns","as"]
s= [['omc','omb'],['h','omb'],  ['h','omc'],['ns','tau'],['as','tau'],
             ['tau','omb'],['tau','omc'],
             ['ns','omb'], ['ns','omc'], ['ns','h'], ['ns','tau'],
             ['as','omb'], ['as','omc'], ['as','h'], ['as','tau'],['as','ns']]
pare = [0.0228,0.1208,67.29,0.0542,0.945,2.0969]
ed = []
for i in s:
    er = r.index(i[0])
    es = r.index(i[1])
    ef = cobaya_2([[arr[er][0],arr[er][1],pare[er]],[arr[es][0],arr[es][1],pare[es]]],r[er],r[es])
    ed.append([ef,r[er],r[es]])
# Out:
# [cosmo] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: Dpar:0.1208, Spar:0.0228
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {cosmo: 172.0}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-02-28 20:10:26 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.928
# [mcmc]  - Convergence of means: R-1 = 9.293123 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# D:\Python\project_cosmology\cospo\lib\site-packages\cobaya\collection.py:651: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._data = pd.concat([
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.883
# [mcmc]  - Convergence of means: R-1 = 2.688574 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.642
# [mcmc]  - Convergence of means: R-1 = 1.129195 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.554
# [mcmc]  - Convergence of means: R-1 = 0.699796 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.444
# [mcmc]  - Convergence of means: R-1 = 0.148281 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.420
# [mcmc]  - Convergence of means: R-1 = 0.118363 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.389
# [mcmc]  - Convergence of means: R-1 = 0.154979 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.357
# [mcmc]  - Convergence of means: R-1 = 0.120243 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.350
# [mcmc]  - Convergence of means: R-1 = 0.086580 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.336
# [mcmc]  - Convergence of means: R-1 = 0.066419 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.038159 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.308
# [mcmc]  - Convergence of means: R-1 = 0.017658 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.028939 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.304
# [mcmc]  - Convergence of means: R-1 = 0.020778 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.287
# [mcmc]  - Convergence of means: R-1 = 0.013015 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.282
# [mcmc]  - Convergence of means: R-1 = 0.004112 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.284
# [mcmc]  - Convergence of means: R-1 = 0.013935 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.275
# [mcmc]  - Convergence of means: R-1 = 0.008298 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.271
# [mcmc]  - Convergence of means: R-1 = 0.009755 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.267
# [mcmc]  - Convergence of means: R-1 = 0.012830 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.269
# [mcmc]  - Convergence of means: R-1 = 0.006291 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.265
# [mcmc]  - Convergence of means: R-1 = 0.007849 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.263
# [mcmc]  - Convergence of means: R-1 = 0.007733 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.260
# [mcmc]  - Convergence of means: R-1 = 0.007173 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.263
# [mcmc]  - Convergence of means: R-1 = 0.017859 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.266
# [mcmc]  - Convergence of means: R-1 = 0.019577 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# [mcmc]  - Acceptance rate: 0.267
# [mcmc]  - Convergence of means: R-1 = 0.018038 after 1728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2240 samples accepted.
# [mcmc]  - Acceptance rate: 0.263
# [mcmc]  - Convergence of means: R-1 = 0.023149 after 1792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2320 samples accepted.
# [mcmc]  - Acceptance rate: 0.261
# [mcmc]  - Convergence of means: R-1 = 0.023056 after 1856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2400 samples accepted.
# [mcmc]  - Acceptance rate: 0.261
# [mcmc]  - Convergence of means: R-1 = 0.040224 after 1920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2480 samples accepted.
# [mcmc]  - Acceptance rate: 0.262
# [mcmc]  - Convergence of means: R-1 = 0.024137 after 1984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2560 samples accepted.
# [mcmc]  - Acceptance rate: 0.263
# [mcmc]  - Convergence of means: R-1 = 0.019824 after 2048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2640 samples accepted.
# [mcmc]  - Acceptance rate: 0.262
# [mcmc]  - Convergence of means: R-1 = 0.017905 after 2112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2720 samples accepted.
# [mcmc]  - Acceptance rate: 0.258
# [mcmc]  - Convergence of means: R-1 = 0.017636 after 2176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2800 samples accepted.
# [mcmc]  - Acceptance rate: 0.257
# [mcmc]  - Convergence of means: R-1 = 0.011111 after 2240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2880 samples accepted.
# [mcmc]  - Acceptance rate: 0.255
# [mcmc]  - Convergence of means: R-1 = 0.010126 after 2304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2960 samples accepted.
# [mcmc]  - Acceptance rate: 0.257
# [mcmc]  - Convergence of means: R-1 = 0.019375 after 2368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3040 samples accepted.
# [mcmc]  - Acceptance rate: 0.256
# [mcmc]  - Convergence of means: R-1 = 0.026595 after 2432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3120 samples accepted.
# [mcmc]  - Acceptance rate: 0.256
# [mcmc]  - Convergence of means: R-1 = 0.020508 after 2496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3200 samples accepted.
# [mcmc]  - Acceptance rate: 0.256
# [mcmc]  - Convergence of means: R-1 = 0.025085 after 2560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3280 samples accepted.
# [mcmc]  - Acceptance rate: 0.256
# [mcmc]  - Convergence of means: R-1 = 0.012385 after 2624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3360 samples accepted.
# [mcmc]  - Acceptance rate: 0.255
# [mcmc]  - Convergence of means: R-1 = 0.009165 after 2688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3440 samples accepted.
# [mcmc]  - Acceptance rate: 0.254
# [mcmc]  - Convergence of means: R-1 = 0.006179 after 2752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3520 samples accepted.
# [mcmc]  - Acceptance rate: 0.254
# [mcmc]  - Convergence of means: R-1 = 0.003375 after 2816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3600 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.006811 after 2880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3680 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.010505 after 2944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3760 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.011062 after 3008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3840 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.008492 after 3072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 3920 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.010266 after 3136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4000 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.016330 after 3200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4080 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.013098 after 3264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4160 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.013412 after 3328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4240 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.016509 after 3392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4320 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.015913 after 3456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4400 samples accepted.
# [mcmc]  - Acceptance rate: 0.245
# [mcmc]  - Convergence of means: R-1 = 0.018435 after 3520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4480 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.016871 after 3584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4560 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.015644 after 3648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4640 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.011099 after 3712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4720 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.007170 after 3776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4800 samples accepted.
# [mcmc]  - Acceptance rate: 0.245
# [mcmc]  - Convergence of means: R-1 = 0.008275 after 3840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4880 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.006143 after 3904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 4960 samples accepted.
# [mcmc]  - Acceptance rate: 0.245
# [mcmc]  - Convergence of means: R-1 = 0.007463 after 3968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5040 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.007128 after 4032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5120 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.003507 after 4096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5200 samples accepted.
# [mcmc]  - Acceptance rate: 0.247
# [mcmc]  - Convergence of means: R-1 = 0.004787 after 4160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5280 samples accepted.
# [mcmc]  - Acceptance rate: 0.247
# [mcmc]  - Convergence of means: R-1 = 0.005413 after 4224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5360 samples accepted.
# [mcmc]  - Acceptance rate: 0.247
# [mcmc]  - Convergence of means: R-1 = 0.005204 after 4288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5440 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.005808 after 4352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5520 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.006866 after 4416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5600 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.005919 after 4480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5680 samples accepted.
# [mcmc]  - Acceptance rate: 0.247
# [mcmc]  - Convergence of means: R-1 = 0.007581 after 4544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5760 samples accepted.
# [mcmc]  - Acceptance rate: 0.249
# [mcmc]  - Convergence of means: R-1 = 0.008555 after 4608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5840 samples accepted.
# [mcmc]  - Acceptance rate: 0.249
# [mcmc]  - Convergence of means: R-1 = 0.008651 after 4672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 5920 samples accepted.
# [mcmc]  - Acceptance rate: 0.249
# [mcmc]  - Convergence of means: R-1 = 0.008047 after 4736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6000 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.007136 after 4800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-28 20:11:26 : 23088 steps taken, and 6049 accepted.
# [mcmc] Learn + convergence test @ 6080 samples accepted.
# [mcmc]  - Acceptance rate: 0.249
# [mcmc]  - Convergence of means: R-1 = 0.008652 after 4864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6160 samples accepted.
# [mcmc]  - Acceptance rate: 0.248
# [mcmc]  - Convergence of means: R-1 = 0.005178 after 4928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6240 samples accepted.
# [mcmc]  - Acceptance rate: 0.248
# [mcmc]  - Convergence of means: R-1 = 0.008007 after 4992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6320 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.009166 after 5056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6400 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007437 after 5120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6480 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007712 after 5184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6560 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.008611 after 5248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6640 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.008596 after 5312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6720 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007431 after 5376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6800 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.004847 after 5440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6880 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.004584 after 5504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 6960 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.003659 after 5568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7040 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.003288 after 5632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7120 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004276 after 5696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7200 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.005250 after 5760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7280 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.005759 after 5824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7360 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.006431 after 5888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7440 samples accepted.
# [mcmc]  - Acceptance rate: 0.253
# [mcmc]  - Convergence of means: R-1 = 0.008770 after 5952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7520 samples accepted.
# [mcmc]  - Acceptance rate: 0.253
# [mcmc]  - Convergence of means: R-1 = 0.007402 after 6016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7600 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.005835 after 6080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7680 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007216 after 6144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7760 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007657 after 6208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7840 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007305 after 6272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 7920 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.006566 after 6336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8000 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.006542 after 6400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8080 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.007814 after 6464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8160 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.007266 after 6528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8240 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.006556 after 6592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8320 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.005690 after 6656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8400 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.005774 after 6720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8480 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.004916 after 6784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8560 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004282 after 6848 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8640 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003020 after 6912 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8720 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001774 after 6976 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8800 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001763 after 7040 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8880 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001730 after 7104 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 8960 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002129 after 7168 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9040 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.002162 after 7232 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9120 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.002466 after 7296 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9200 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.002228 after 7360 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9280 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.002727 after 7424 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9360 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001979 after 7488 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9440 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001023 after 7552 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9520 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001029 after 7616 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9600 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.000816 after 7680 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9680 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001546 after 7744 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9760 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001328 after 7808 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9840 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001786 after 7872 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 9920 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.001793 after 7936 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10000 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.002151 after 8000 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10080 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002515 after 8064 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10160 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002132 after 8128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10240 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001768 after 8192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10320 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001290 after 8256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10400 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001958 after 8320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10480 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003024 after 8384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10560 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002548 after 8448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10640 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002862 after 8512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10720 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002312 after 8576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10800 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.003129 after 8640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10880 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002056 after 8704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 10960 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002325 after 8768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11040 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002271 after 8832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11120 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002747 after 8896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11200 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002588 after 8960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11280 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002592 after 9024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11360 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002712 after 9088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11440 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002524 after 9152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11520 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003314 after 9216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11600 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.003512 after 9280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11680 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.003770 after 9344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11760 samples accepted.
# [mcmc]  - Acceptance rate: 0.252
# [mcmc]  - Convergence of means: R-1 = 0.003669 after 9408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11840 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003690 after 9472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 11920 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003132 after 9536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12000 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003053 after 9600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12080 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004299 after 9664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12160 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004683 after 9728 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12240 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004189 after 9792 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Progress @ 2024-02-28 20:12:26 : 47660 steps taken, and 12263 accepted.
# [mcmc] Learn + convergence test @ 12320 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.003739 after 9856 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12400 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004159 after 9920 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12480 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.004305 after 9984 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12560 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003820 after 10048 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12640 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003890 after 10112 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12720 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003202 after 10176 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12800 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002789 after 10240 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12880 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002706 after 10304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12960 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002644 after 10368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13040 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002230 after 10432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13120 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.001941 after 10496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13200 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001325 after 10560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13280 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001373 after 10624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13360 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001654 after 10688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13440 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002039 after 10752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13520 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002057 after 10816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13600 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001945 after 10880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13680 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002257 after 10944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13760 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002076 after 11008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13840 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.002097 after 11072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13920 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002085 after 11136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14000 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003389 after 11200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14080 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.003205 after 11264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14160 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.002264 after 11328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14240 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001616 after 11392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14320 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001558 after 11456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14400 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001272 after 11520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14480 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001395 after 11584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14560 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.001134 after 11648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14640 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.000969 after 11712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14720 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.001107 after 11776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14800 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.000729 after 11840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14880 samples accepted.
# [mcmc]  - Acceptance rate: 0.251
# [mcmc]  - Convergence of means: R-1 = 0.000689 after 11904 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.031227 after 14880 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 14880 accepted steps.
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'
# [cosmo] Initialized external likelihood.
# [mcmc] Getting initial point... (this may take a few seconds)
# [mcmc] Initial point: Dpar:67.29, Spar:0.0228
# [model] Measuring speeds... (this may take a few seconds)
# [model] Setting measured speeds (per sec): {cosmo: 127.0}
# [mcmc] Covariance matrix not present. We will start learning the covariance of the proposal earlier: R-1 = 30 (would be 2 if all params loaded).
# [mcmc] Sampling!
# [mcmc] Progress @ 2024-02-28 20:12:51 : 1 steps taken, and 0 accepted.
# [mcmc] Learn + convergence test @ 80 samples accepted.
# [mcmc]  - Acceptance rate: 0.865
# [mcmc]  - Convergence of means: R-1 = 3.008236 after 64 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# D:\Python\project_cosmology\cospo\lib\site-packages\cobaya\collection.py:651: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   self._data = pd.concat([
# [mcmc] Learn + convergence test @ 160 samples accepted.
# [mcmc]  - Acceptance rate: 0.831
# [mcmc]  - Convergence of means: R-1 = 10.499496 after 128 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 240 samples accepted.
# [mcmc]  - Acceptance rate: 0.621
# [mcmc]  - Convergence of means: R-1 = 1.302928 after 192 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 320 samples accepted.
# [mcmc]  - Acceptance rate: 0.509
# [mcmc]  - Convergence of means: R-1 = 0.251735 after 256 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 400 samples accepted.
# [mcmc]  - Acceptance rate: 0.460
# [mcmc]  - Convergence of means: R-1 = 0.225626 after 320 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 480 samples accepted.
# [mcmc]  - Acceptance rate: 0.432
# [mcmc]  - Convergence of means: R-1 = 0.187056 after 384 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 560 samples accepted.
# [mcmc]  - Acceptance rate: 0.403
# [mcmc]  - Convergence of means: R-1 = 0.154312 after 448 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 640 samples accepted.
# [mcmc]  - Acceptance rate: 0.380
# [mcmc]  - Convergence of means: R-1 = 0.269779 after 512 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 720 samples accepted.
# [mcmc]  - Acceptance rate: 0.356
# [mcmc]  - Convergence of means: R-1 = 0.240498 after 576 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 800 samples accepted.
# [mcmc]  - Acceptance rate: 0.338
# [mcmc]  - Convergence of means: R-1 = 0.203336 after 640 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 880 samples accepted.
# [mcmc]  - Acceptance rate: 0.332
# [mcmc]  - Convergence of means: R-1 = 0.159817 after 704 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 960 samples accepted.
# [mcmc]  - Acceptance rate: 0.320
# [mcmc]  - Convergence of means: R-1 = 0.128028 after 768 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1040 samples accepted.
# [mcmc]  - Acceptance rate: 0.307
# [mcmc]  - Convergence of means: R-1 = 0.095955 after 832 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1120 samples accepted.
# [mcmc]  - Acceptance rate: 0.294
# [mcmc]  - Convergence of means: R-1 = 0.089456 after 896 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1200 samples accepted.
# [mcmc]  - Acceptance rate: 0.277
# [mcmc]  - Convergence of means: R-1 = 0.102916 after 960 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1280 samples accepted.
# [mcmc]  - Acceptance rate: 0.269
# [mcmc]  - Convergence of means: R-1 = 0.091294 after 1024 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1360 samples accepted.
# [mcmc]  - Acceptance rate: 0.263
# [mcmc]  - Convergence of means: R-1 = 0.057324 after 1088 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1440 samples accepted.
# [mcmc]  - Acceptance rate: 0.254
# [mcmc]  - Convergence of means: R-1 = 0.036611 after 1152 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1520 samples accepted.
# [mcmc]  - Acceptance rate: 0.250
# [mcmc]  - Convergence of means: R-1 = 0.027125 after 1216 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1600 samples accepted.
# [mcmc]  - Acceptance rate: 0.244
# [mcmc]  - Convergence of means: R-1 = 0.049335 after 1280 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1680 samples accepted.
# [mcmc]  - Acceptance rate: 0.246
# [mcmc]  - Convergence of means: R-1 = 0.077721 after 1344 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1760 samples accepted.
# [mcmc]  - Acceptance rate: 0.241
# [mcmc]  - Convergence of means: R-1 = 0.079854 after 1408 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1840 samples accepted.
# [mcmc]  - Acceptance rate: 0.239
# [mcmc]  - Convergence of means: R-1 = 0.059939 after 1472 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 1920 samples accepted.
# [mcmc]  - Acceptance rate: 0.236
# [mcmc]  - Convergence of means: R-1 = 0.033424 after 1536 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2000 samples accepted.
# [mcmc]  - Acceptance rate: 0.236
# [mcmc]  - Convergence of means: R-1 = 0.033880 after 1600 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2080 samples accepted.
# [mcmc]  - Acceptance rate: 0.235
# [mcmc]  - Convergence of means: R-1 = 0.029445 after 1664 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 2160 samples accepted.
# ...
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12880 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.003440 after 10304 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 12960 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.003540 after 10368 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13040 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002640 after 10432 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13120 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002470 after 10496 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13200 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002288 after 10560 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13280 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002759 after 10624 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13360 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002657 after 10688 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13440 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002674 after 10752 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13520 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002931 after 10816 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13600 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002856 after 10880 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13680 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002899 after 10944 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13760 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003602 after 11008 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13840 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003343 after 11072 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 13920 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003446 after 11136 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14000 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003210 after 11200 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14080 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003367 after 11264 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14160 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.004240 after 11328 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14240 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.004434 after 11392 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14320 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.004110 after 11456 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14400 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003639 after 11520 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14480 samples accepted.
# [mcmc]  - Acceptance rate: 0.303
# [mcmc]  - Convergence of means: R-1 = 0.003960 after 11584 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14560 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003649 after 11648 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14640 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003575 after 11712 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14720 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003031 after 11776 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14800 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003225 after 11840 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14880 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003362 after 11904 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 14960 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003326 after 11968 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15040 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003183 after 12032 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15120 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003046 after 12096 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15200 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003531 after 12160 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15280 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003542 after 12224 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15360 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003287 after 12288 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15440 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003316 after 12352 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15520 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003942 after 12416 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15600 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.004051 after 12480 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15680 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.004343 after 12544 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15760 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.004011 after 12608 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15840 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.003247 after 12672 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 15920 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.003016 after 12736 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16000 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002936 after 12800 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16080 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002998 after 12864 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16160 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.003005 after 12928 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16240 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.003326 after 12992 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16320 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002666 after 13056 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16400 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.003001 after 13120 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16480 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002833 after 13184 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16560 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002697 after 13248 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16640 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002623 after 13312 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16720 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002645 after 13376 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16800 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002414 after 13440 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16880 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002172 after 13504 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 16960 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002338 after 13568 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17040 samples accepted.
# [mcmc]  - Acceptance rate: 0.302
# [mcmc]  - Convergence of means: R-1 = 0.002010 after 13632 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17120 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.001969 after 13696 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17200 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.001864 after 13760 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17280 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.001896 after 13824 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17360 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002504 after 13888 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17440 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002385 after 13952 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17520 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002183 after 14016 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17600 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002265 after 14080 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17680 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.002117 after 14144 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17760 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.002606 after 14208 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17840 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.002035 after 14272 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 17920 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.001991 after 14336 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18000 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.001721 after 14400 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18080 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.001747 after 14464 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18160 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.001683 after 14528 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18240 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.001311 after 14592 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18320 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.001026 after 14656 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18400 samples accepted.
# [mcmc]  - Acceptance rate: 0.300
# [mcmc]  - Convergence of means: R-1 = 0.001033 after 14720 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18480 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.000802 after 14784 accepted steps
# [mcmc]  - Updated covariance matrix of proposal pdf.
# [mcmc] Learn + convergence test @ 18560 samples accepted.
# [mcmc]  - Acceptance rate: 0.301
# [mcmc]  - Convergence of means: R-1 = 0.000742 after 14848 accepted steps
# [mcmc]  - Convergence of bounds: R-1 = 0.038670 after 18560 accepted steps
# [mcmc] The run has converged!
# [mcmc] Sampling complete after 18560 accepted steps.
# [mcmc] *WARNING* When combining chains, it is recommended to remove some initial fraction, e.g. 'skip_samples=0.3'

# %%
for i in ed:
    print(i[1],'is',i[0][0],'and',i[2],'is', i[0][1] )
# Out:
# omc is 0.12020465047374419 and omb is 0.022415125531444518
# h is 67.03139193110552 and omb is 0.022450375917672016
# h is 67.67104971111291 and omc is 0.11969113205544821
# ns is 0.9646351613201951 and tau is 0.05469178952691677
# as is 2.1138706975331796 and tau is 0.053989335111119446
# tau is 0.05026018485925455 and omb is 0.022525900274524873
# tau is 0.05023610058087108 and omc is 0.12152826702854988
# ns is 0.9679049617603407 and omb is 0.022183827615787816
# ns is 0.9683229926820839 and omc is 0.12196182306338328
# ns is 0.9693492180249461 and h is 67.99196502573153
# ns is 0.9644249687635805 and tau is 0.05483132608159998
# as is 2.1183044071249353 and omb is 0.022370626826104644
# as is 2.1289797926691474 and omc is 0.12281626888666414
# as is 2.119517507451343 and h is 67.72782963968959
# as is 2.1136450382785568 and tau is 0.05397908572036012
# as is 2.0957896942731176 and ns is 0.9638824058427248

# %%
[[[0.12020465047374419, 0.022415125531444518], 'omc', 'omb'], [[67.03139193110552, 0.022450375917672016], 'h', 'omb'], [[67.67104971111291, 0.11969113205544821], 'h', 'omc'], [[0.9646351613201951, 0.05469178952691677], 'ns', 'tau'], [[2.1138706975331796, 0.053989335111119446], 'as', 'tau'], [[0.05026018485925455, 0.022525900274524873], 'tau', 'omb'], [[0.05023610058087108, 0.12152826702854988], 'tau', 'omc'], [[0.9679049617603407, 0.022183827615787816], 'ns', 'omb'], [[0.9683229926820839, 0.12196182306338328], 'ns', 'omc'], [[0.9693492180249461, 67.99196502573153], 'ns', 'h'], [[0.9644249687635805, 0.05483132608159998], 'ns', 'tau'], [[2.1183044071249353, 0.022370626826104644], 'as', 'omb'], [[2.1289797926691474, 0.12281626888666414], 'as', 'omc'], [[2.119517507451343, 67.72782963968959], 'as', 'h'], [[2.1136450382785568, 0.05397908572036012], 'as', 'tau'], [[2.0957896942731176, 0.9638824058427248], 'as', 'ns']]

'''
omc is 0.12020465047374419 and omb is 0.022415125531444518
h is 67.03139193110552 and omb is 0.022450375917672016
h is 67.67104971111291 and omc is 0.11969113205544821
ns is 0.9646351613201951 and tau is 0.05469178952691677
as is 2.1138706975331796 and tau is 0.053989335111119446
tau is 0.05026018485925455 and omb is 0.022525900274524873
tau is 0.05023610058087108 and omc is 0.12152826702854988
ns is 0.9679049617603407 and omb is 0.022183827615787816
ns is 0.9683229926820839 and omc is 0.12196182306338328
ns is 0.9693492180249461 and h is 67.99196502573153
ns is 0.9644249687635805 and tau is 0.05483132608159998
as is 2.1183044071249353 and omb is 0.022370626826104644
as is 2.1289797926691474 and omc is 0.12281626888666414
as is 2.119517507451343 and h is 67.72782963968959
as is 2.1136450382785568 and tau is 0.05397908572036012
as is 2.0957896942731176 and ns is 0.9638824058427248 '''
# Out:
# '\nomc is 0.12020465047374419 and omb is 0.022415125531444518\nh is 67.03139193110552 and omb is 0.022450375917672016\nh is 67.67104971111291 and omc is 0.11969113205544821\nns is 0.9646351613201951 and tau is 0.05469178952691677\nas is 2.1138706975331796 and tau is 0.053989335111119446\ntau is 0.05026018485925455 and omb is 0.022525900274524873\ntau is 0.05023610058087108 and omc is 0.12152826702854988\nns is 0.9679049617603407 and omb is 0.022183827615787816\nns is 0.9683229926820839 and omc is 0.12196182306338328\nns is 0.9693492180249461 and h is 67.99196502573153\nns is 0.9644249687635805 and tau is 0.05483132608159998\nas is 2.1183044071249353 and omb is 0.022370626826104644\nas is 2.1289797926691474 and omc is 0.12281626888666414\nas is 2.119517507451343 and h is 67.72782963968959\nas is 2.1136450382785568 and tau is 0.05397908572036012\nas is 2.0957896942731176 and ns is 0.9638824058427248 '

# %%
ar =  [[[0.0219, 0.12200000000000008, 66.956, 0.05098, 0.96868, 2.1094], 'omb', 'omc'], [[0.02239999999999998, 0.12056, 68.29000000000092, 0.05098, 0.96868, 2.1094], 'omb', 'h'], [[0.021929999999999998, 0.12056, 66.956, 0.05820000000000024, 0.96868, 2.1094], 'omb', 'tau'], [[0.0219, 0.12056, 66.956, 0.05098, 0.9542999999999974, 2.1094], 'omb', 'ns'], [[0.02192, 0.12056, 66.956, 0.05098, 0.96868, 2.0793000000000195], 'omb', 'as'], [[0.02228, 0.12200000000000008, 67.61000000000057, 0.05098, 0.96868, 2.1094], 'omc', 'h'], [[0.02228, 0.12200000000000008, 66.956, 0.05650000000000019, 0.96868, 2.1094], 'omc', 'tau'], [[0.02228, 0.12200000000000008, 66.956, 0.05098, 0.9559999999999972, 2.1094], 'omc', 'ns'], [[0.02228, 0.12200000000000008, 66.956, 0.05098, 0.96868, 2.086200000000034], 'omc', 'as'],
[[0.02228, 0.12056, 67.60000000000056, 0.05730000000000021, 0.96868, 2.1094], 'h', 'tau'], [[0.02228, 0.12056, 67.84000000000069, 0.05098, 0.958099999999997, 2.1094], 'h', 'ns'], [[0.02228, 0.12056, 67.60000000000056, 0.05098, 0.96868, 2.0830000000000273], 'h', 'as'],
[[0.02228, 0.12056, 66.956, 0.05830000000000024, 0.9659999999999961, 2.1094], 'tau', 'ns'], [[0.02228, 0.12056, 66.956, 0.059900000000000286, 0.96868, 2.1134000000000914], 'tau', 'as'], [[0.02228, 0.12056, 66.956, 0.05098, 0.9659999999999961, 2.0788000000000184], 'ns', 'as']    
]
pars = ["omb","omc","h","tau","ns","as"]
par = [[],[],[],[],[],[]]
for i in ar:
    par[pars.index(i[1])].append(i[0][pars.index(i[1])])
    par[pars.index(i[2])].append(i[0][pars.index(i[2])])
    #print(i[1],":",i[0][pars.index(i[1])],i[2],":",i[0][pars.index(i[2])])
pam = [[],[],[],[],[],[]]
for i in range(len(pars)):
    pam[i].append([pars[i],[np.average(par[i])],[np.std(par[i])]])
for i in pam:
    print(i[0][0],':',np.round(i[0][1],5),'+-',np.round(i[0][2],10))
# Out:
# omb : [0.02201] +- [0.00019535]
# omc : [0.122] +- [0.]
# h : [67.788] +- [0.26723772]
# tau : [0.05804] +- [0.00113772]
# ns : [0.96008] +- [0.00498133]
# as : [2.08814] +- [0.01291226]

# %%
ar = [[[0.12020465047374419, 0.022415125531444518], 'omc', 'omb'], [[67.03139193110552, 0.022450375917672016], 'h', 'omb'], [[67.67104971111291, 0.11969113205544821], 'h', 'omc'], [[0.9646351613201951, 0.05469178952691677], 'ns', 'tau'], [[2.1138706975331796, 0.053989335111119446], 'as', 'tau'], [[0.05026018485925455, 0.022525900274524873], 'tau', 'omb'], [[0.05023610058087108, 0.12152826702854988], 'tau', 'omc'], [[0.9679049617603407, 0.022183827615787816], 'ns', 'omb'], [[0.9683229926820839, 0.12196182306338328], 'ns', 'omc'], [[0.9693492180249461, 67.99196502573153], 'ns', 'h'], [[0.9644249687635805, 0.05483132608159998], 'ns', 'tau'], [[2.1183044071249353, 0.022370626826104644], 'as', 'omb'], [[2.1289797926691474, 0.12281626888666414], 'as', 'omc'], [[2.119517507451343, 67.72782963968959], 'as', 'h'], [[2.1136450382785568, 0.05397908572036012], 'as', 'tau'], [[2.0957896942731176, 0.9638824058427248], 'as', 'ns']]

pars = ["omb","omc","h","tau","ns","as"]
par = [[],[],[],[],[],[]]
for i in ar:
    par[pars.index(i[1])].append(i[0][0])
    par[pars.index(i[2])].append(i[0][1])
    #print(i[1],":",i[0][pars.index(i[1])],i[2],":",i[0][pars.index(i[2])])
pam_c = [[],[],[],[],[],[]]
for i in range(len(pars)):
    pam_c[i].append([pars[i],[np.average(par[i])],[np.std(par[i])]])
for i in pam_c:
    print(i[0][0],':',np.round(i[0][1],5),'+-',np.round(i[0][2],10))
print("<table>")
print("<tr><th>Parameters</th><th>Double</th><th>Error</th><th>Cobaya</th><th>Error</th></tr>")
for i in range(6):
    print("<tr>")
    print("<th>",pam_c[i][0][0],"</th>")
    print("<td>",np.round(pam[i][0][1],5),"</td>")
    print("<td>",np.round(pam[i][0][2],5),"</td>")
    print("<td>",np.round(pam_c[i][0][1],5),"</td>")
    print("<td>",np.round(pam_c[i][0][2],5),"</td>")
    print("</tr>")

print("</table>")
# Out:
# omb : [0.02239] +- [0.00011456]
# omc : [0.12124] +- [0.0011454]
# h : [67.60556] +- [0.35292229]
# tau : [0.053] +- [0.00197058]
# ns : [0.96642] +- [0.00216071]
# as : [2.11502] +- [0.00999089]
# <table>
# <tr><th>Parameters</th><th>Double</th><th>Error</th><th>Cobaya</th><th>Error</th></tr>
# <tr>
# <th> omb </th>
# <td> [0.02201] </td>
# <td> [0.0002] </td>
# <td> [0.02239] </td>
# <td> [0.00011] </td>
# </tr>
# <tr>
# <th> omc </th>
# <td> [0.122] </td>
# <td> [0.] </td>
# <td> [0.12124] </td>
# <td> [0.00115] </td>
# </tr>
# <tr>
# <th> h </th>
# <td> [67.788] </td>
# <td> [0.26724] </td>
# <td> [67.60556] </td>
# <td> [0.35292] </td>
# </tr>
# <tr>
# <th> tau </th>
# <td> [0.05804] </td>
# <td> [0.00114] </td>
# <td> [0.053] </td>
# <td> [0.00197] </td>
# </tr>
# <tr>
# <th> ns </th>
# <td> [0.96008] </td>
# <td> [0.00498] </td>
# <td> [0.96642] </td>
# <td> [0.00216] </td>
# </tr>
# <tr>
# <th> as </th>
# <td> [2.08814] </td>
# <td> [0.01291] </td>
# <td> [2.11502] </td>
# <td> [0.00999] </td>
# </tr>
# </table>

# %% [markdown]
# <table>
# <tr><th>Parameters</th><th>Double</th><th>Error</th><th>Cobaya</th><th>Error</th></tr>
# <tr>
# <th> omb </th>
# <td> [0.02201] </td>
# <td> [0.0002] </td>
# <td> [0.02239] </td>
# <td> [0.00011] </td>
# </tr>
# <tr>
# <th> omc </th>
# <td> [0.122] </td>
# <td> [0.0004633] </td>
# <td> [0.12124] </td>
# <td> [0.00115] </td>
# </tr>
# <tr>
# <th> h </th>
# <td> [67.788] </td>
# <td> [0.26724] </td>
# <td> [67.60556] </td>
# <td> [0.35292] </td>
# </tr>
# <tr>
# <th> tau </th>
# <td> [0.05804] </td>
# <td> [0.00114] </td>
# <td> [0.053] </td>
# <td> [0.00197] </td>
# </tr>
# <tr>
# <th> ns </th>
# <td> [0.96008] </td>
# <td> [0.00498] </td>
# <td> [0.96642] </td>
# <td> [0.00216] </td>
# </tr>
# <tr>
# <th> as </th>
# <td> [2.08814] </td>
# <td> [0.01291] </td>
# <td> [2.11502] </td>
# <td> [0.00999] </td>
# </tr>
# </table>
